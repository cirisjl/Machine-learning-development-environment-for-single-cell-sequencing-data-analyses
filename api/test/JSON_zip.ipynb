# %%
import base64           # 导入 base64 模块
import gzip             # 导入 gzip 模块
import json             # 导入 json 模块
import pandas as pd
from io import BytesIO  # 从 io 模块导入 BytesIO 类

# %%
def gzip_str(to_gzip: str) -> str:
    out = BytesIO()
    with gzip.GzipFile(fileobj=out, mode='w') as f: 
        f.write(to_gzip.encode())
    return base64.b64encode(out.getvalue()).decode()


def ungzip_str(to_ungzip: str) -> str:
    compressed = base64.b64decode(to_ungzip) 
    with gzip.GzipFile(fileobj=BytesIO(compressed)) as f: 
        return f.read().decode()
    

def gzip_dict(to_gzip: dict) -> str:
    jsonStr = json.dumps(to_gzip)
    return gzip_str(jsonStr)


def ungzip_dict(to_ungzip: str) -> dict:
    jsonStr = ungzip_str(to_ungzip)
    return json.loads(jsonStr)


def gzip_df(to_gzip: pd.DataFrame) -> str:
    # dropping null value columns to avoid errors 
    # to_gzip.dropna(inplace = False) 
    
    # converting to dict 
    dfDict = to_gzip.to_dict('list') 
    return gzip_dict(dfDict)


def ungzip_df(to_ungzip: str) -> pd.DataFrame:
    dfDict = ungzip_dict(to_ungzip)
    return pd.DataFrame.from_dict(dfDict)

# %%
with open('pp_results.json', 'r', encoding='utf-8') as f:
    jsonData = json.load(f)

# %%
type(jsonData)

# %%
# 将字典转换为JSON字符串
jsonData = jsonData['umap_plot_3d']

jsonStr = json.dumps(jsonData)

# %%
jsonStr

# %%
type(jsonStr)

# %%
jsonStr1 = json.loads(jsonStr)
type(jsonStr1)

# %%
jsonStr1

# %%
jsonStr2 = eval(jsonStr)
type(jsonStr2)

# %%
jsonStr2

# %%
# 打印JSON字符串
# print("原始json字符串：", jsonStr)
print("原始json字符串长度：", len(jsonStr))
zipStr = gzip_str(jsonStr)
# print("压缩编码后的json字符串：", zipStr)
print("压缩编码后的json字符串长度：", len(zipStr))
unzipStr = ungzip_str(zipStr)
# print("解压缩后的json字符串：", unzipStr)
print("解压缩后的json字符串长度：", len(unzipStr))
if jsonStr == unzipStr:
    print("源字符串和解压后的字符串相同")
else:
    print("源字符串和解压后的字符串不同")

# %%
import sys
sys.path.append('..')
from tools.formating.formating import *
  
# input = "/ps/ai-ready/data/Clustering/Tabula_Muris/droplet_Bladder_seurat_tiss.h5ad"
# input = "/ps/oscb/user_storage/Benchmarks/dropletTrachea_1727314308745/QC/droplet_Trachea_Seurat.h5ad"
input = "/ps/oscb/user_storage/Benchmarks/dropletBladder_1727296846245/QC/droplet_Bladder_Seurat.h5ad"
adata = load_anndata(input)
adata
# Out:
# /ps/oscb/user_storage/Benchmarks/dropletBladder_1727296846245/QC/droplet_Bladder_Seurat.h5ad
# AnnData object with n_obs × n_vars = 2300 × 23341
#     obs: 'orig.ident', 'n_counts', 'n_genes', 'channel', 'tissue', 'subtissue', 'mouse.sex', 'mouse.id', 'percent.ercc', 'percent.ribo', 'free_annotation', 'cell_ontology_class', 'res.0.4', 'previous_free_annotation', 'previous_cell_ontology_class', 'cluster.ids', 'cell_ontology_id', 'pct_counts_mt', 'pct_counts_rb', 'pct_counts_hb', 'percent.plat', 'RNA_snn_res.0.5', 'seurat_clusters', 'doublet_score', 'doublet_class'
#     var: 'vst.mean', 'vst.variance', 'vst.variance.expected', 'vst.variance.standardized', 'highly_variable'
#     uns: 'neighbors'
#     obsm: 'X_pca', 'X_tsne', 'X_umap', 'X_umap_3D'
#     layers: 'scale.data'
#     obsp: 'connectivities', 'distances'

# %%
df_list = adata.obs.to_dict('list')
df_list["index"] = adata.obs.index

# %%
df = pd.DataFrame.from_dict(df_list)
df
# Out:
#      orig.ident  n_counts  n_genes   channel   tissue subtissue mouse.sex  \
# 0           10X   10291.0     2853  10X_P4_3  Bladder                   M
# 1           10X   12944.0     3347  10X_P4_3  Bladder                   M
# 2           10X   19594.0     3851  10X_P4_3  Bladder                   M
# 3           10X   14594.0     3809  10X_P4_3  Bladder                   M
# 4           10X    5005.0     1960  10X_P4_3  Bladder                   M
# ...         ...       ...      ...       ...      ...       ...       ...
# 2295        10X   50069.0     5641  10X_P7_7  Bladder                   F
# 2296        10X    9666.0     3087  10X_P7_7  Bladder                   F
# 2297        10X   22993.0     4296  10X_P7_7  Bladder                   F
# 2298        10X    8753.0     3005  10X_P7_7  Bladder                   F
# 2299        10X   14665.0     3778  10X_P7_7  Bladder                   F
#
#      mouse.id  percent.ercc  percent.ribo  ... cell_ontology_id pct_counts_mt  \
# 0       3-M-8           0.0      0.219609  ...       CL:1001319           0.0
# 1       3-M-8           0.0      0.192444  ...       CL:1001319           0.0
# 2       3-M-8           0.0      0.356385  ...       CL:1001428           0.0
# 3       3-M-8           0.0      0.157119  ...       CL:1001319           0.0
# 4       3-M-8           0.0      0.190210  ...       CL:1001319           0.0
# ...       ...           ...           ...  ...              ...           ...
# 2295   3-F-56           0.0      0.400407  ...       CL:1001428           0.0
# 2296   3-F-56           0.0      0.108628  ...       CL:0000115           0.0
# 2297   3-F-56           0.0      0.286783  ...       CL:1001428           0.0
# 2298   3-F-56           0.0      0.120873  ...       CL:1001319           0.0
# 2299   3-F-56           0.0      0.118173  ...       CL:1001319           0.0
#
#      pct_counts_rb pct_counts_hb percent.plat RNA_snn_res.0.5 seurat_clusters  \
# 0              0.0           0.0          0.0               6               6
# 1              0.0           0.0          0.0               0               0
# 2              0.0           0.0          0.0               3               3
# 3              0.0           0.0          0.0               0               0
# 4              0.0           0.0          0.0               6               6
# ...            ...           ...          ...             ...             ...
# 2295           0.0           0.0          0.0               3               3
# 2296           0.0           0.0          0.0               9               9
# 2297           0.0           0.0          0.0               7               7
# 2298           0.0           0.0          0.0               5               5
# 2299           0.0           0.0          0.0               5               5
#
#       doublet_score  doublet_class                      index
# 0          0.110000        Singlet  10X_P4_3_AAAGTAGAGATGCCAG
# 1          0.263333        Singlet  10X_P4_3_AACTCCCGTCGGGTCT
# 2          0.270000        Singlet  10X_P4_3_AACTCTTAGTTGCAGG
# 3          0.286667        Singlet  10X_P4_3_AACTCTTTCATAACCG
# 4          0.063333        Singlet  10X_P4_3_AAGGAGCGTGCAACTT
# ...             ...            ...                        ...
# 2295       0.260000        Singlet  10X_P7_7_TTGGAACGTGTCGCTG
# 2296       0.260000        Singlet  10X_P7_7_TTGTAGGCACTTGGAT
# 2297       0.240000        Singlet  10X_P7_7_TTGTAGGTCATGTAGC
# 2298       0.206667        Singlet  10X_P7_7_TTTACTGGTGTTGAGG
# 2299       0.203333        Singlet  10X_P7_7_TTTCCTCCATACCATG
#
# [2300 rows x 26 columns]

# %%
df = df.set_index(adata.obs.index)
df
# Out:
#                           orig.ident  n_counts  n_genes   channel   tissue  \
# 10X_P4_3_AAAGTAGAGATGCCAG        10X   10291.0     2853  10X_P4_3  Bladder
# 10X_P4_3_AACTCCCGTCGGGTCT        10X   12944.0     3347  10X_P4_3  Bladder
# 10X_P4_3_AACTCTTAGTTGCAGG        10X   19594.0     3851  10X_P4_3  Bladder
# 10X_P4_3_AACTCTTTCATAACCG        10X   14594.0     3809  10X_P4_3  Bladder
# 10X_P4_3_AAGGAGCGTGCAACTT        10X    5005.0     1960  10X_P4_3  Bladder
# ...                              ...       ...      ...       ...      ...
# 10X_P7_7_TTGGAACGTGTCGCTG        10X   50069.0     5641  10X_P7_7  Bladder
# 10X_P7_7_TTGTAGGCACTTGGAT        10X    9666.0     3087  10X_P7_7  Bladder
# 10X_P7_7_TTGTAGGTCATGTAGC        10X   22993.0     4296  10X_P7_7  Bladder
# 10X_P7_7_TTTACTGGTGTTGAGG        10X    8753.0     3005  10X_P7_7  Bladder
# 10X_P7_7_TTTCCTCCATACCATG        10X   14665.0     3778  10X_P7_7  Bladder
#
#                           subtissue mouse.sex mouse.id  percent.ercc  \
# 10X_P4_3_AAAGTAGAGATGCCAG                   M    3-M-8           0.0
# 10X_P4_3_AACTCCCGTCGGGTCT                   M    3-M-8           0.0
# 10X_P4_3_AACTCTTAGTTGCAGG                   M    3-M-8           0.0
# 10X_P4_3_AACTCTTTCATAACCG                   M    3-M-8           0.0
# 10X_P4_3_AAGGAGCGTGCAACTT                   M    3-M-8           0.0
# ...                             ...       ...      ...           ...
# 10X_P7_7_TTGGAACGTGTCGCTG                   F   3-F-56           0.0
# 10X_P7_7_TTGTAGGCACTTGGAT                   F   3-F-56           0.0
# 10X_P7_7_TTGTAGGTCATGTAGC                   F   3-F-56           0.0
# 10X_P7_7_TTTACTGGTGTTGAGG                   F   3-F-56           0.0
# 10X_P7_7_TTTCCTCCATACCATG                   F   3-F-56           0.0
#
#                            percent.ribo  ... cell_ontology_id pct_counts_mt  \
# 10X_P4_3_AAAGTAGAGATGCCAG      0.219609  ...       CL:1001319           0.0
# 10X_P4_3_AACTCCCGTCGGGTCT      0.192444  ...       CL:1001319           0.0
# 10X_P4_3_AACTCTTAGTTGCAGG      0.356385  ...       CL:1001428           0.0
# 10X_P4_3_AACTCTTTCATAACCG      0.157119  ...       CL:1001319           0.0
# 10X_P4_3_AAGGAGCGTGCAACTT      0.190210  ...       CL:1001319           0.0
# ...                                 ...  ...              ...           ...
# 10X_P7_7_TTGGAACGTGTCGCTG      0.400407  ...       CL:1001428           0.0
# 10X_P7_7_TTGTAGGCACTTGGAT      0.108628  ...       CL:0000115           0.0
# 10X_P7_7_TTGTAGGTCATGTAGC      0.286783  ...       CL:1001428           0.0
# 10X_P7_7_TTTACTGGTGTTGAGG      0.120873  ...       CL:1001319           0.0
# 10X_P7_7_TTTCCTCCATACCATG      0.118173  ...       CL:1001319           0.0
#
#                           pct_counts_rb pct_counts_hb percent.plat  \
# 10X_P4_3_AAAGTAGAGATGCCAG           0.0           0.0          0.0
# 10X_P4_3_AACTCCCGTCGGGTCT           0.0           0.0          0.0
# 10X_P4_3_AACTCTTAGTTGCAGG           0.0           0.0          0.0
# 10X_P4_3_AACTCTTTCATAACCG           0.0           0.0          0.0
# 10X_P4_3_AAGGAGCGTGCAACTT           0.0           0.0          0.0
# ...                                 ...           ...          ...
# 10X_P7_7_TTGGAACGTGTCGCTG           0.0           0.0          0.0
# 10X_P7_7_TTGTAGGCACTTGGAT           0.0           0.0          0.0
# 10X_P7_7_TTGTAGGTCATGTAGC           0.0           0.0          0.0
# 10X_P7_7_TTTACTGGTGTTGAGG           0.0           0.0          0.0
# 10X_P7_7_TTTCCTCCATACCATG           0.0           0.0          0.0
#
#                           RNA_snn_res.0.5 seurat_clusters  doublet_score  \
# 10X_P4_3_AAAGTAGAGATGCCAG               6               6       0.110000
# 10X_P4_3_AACTCCCGTCGGGTCT               0               0       0.263333
# 10X_P4_3_AACTCTTAGTTGCAGG               3               3       0.270000
# 10X_P4_3_AACTCTTTCATAACCG               0               0       0.286667
# 10X_P4_3_AAGGAGCGTGCAACTT               6               6       0.063333
# ...                                   ...             ...            ...
# 10X_P7_7_TTGGAACGTGTCGCTG               3               3       0.260000
# 10X_P7_7_TTGTAGGCACTTGGAT               9               9       0.260000
# 10X_P7_7_TTGTAGGTCATGTAGC               7               7       0.240000
# 10X_P7_7_TTTACTGGTGTTGAGG               5               5       0.206667
# 10X_P7_7_TTTCCTCCATACCATG               5               5       0.203333
#
#                            doublet_class                      index
# 10X_P4_3_AAAGTAGAGATGCCAG        Singlet  10X_P4_3_AAAGTAGAGATGCCAG
# 10X_P4_3_AACTCCCGTCGGGTCT        Singlet  10X_P4_3_AACTCCCGTCGGGTCT
# 10X_P4_3_AACTCTTAGTTGCAGG        Singlet  10X_P4_3_AACTCTTAGTTGCAGG
# 10X_P4_3_AACTCTTTCATAACCG        Singlet  10X_P4_3_AACTCTTTCATAACCG
# 10X_P4_3_AAGGAGCGTGCAACTT        Singlet  10X_P4_3_AAGGAGCGTGCAACTT
# ...                                  ...                        ...
# 10X_P7_7_TTGGAACGTGTCGCTG        Singlet  10X_P7_7_TTGGAACGTGTCGCTG
# 10X_P7_7_TTGTAGGCACTTGGAT        Singlet  10X_P7_7_TTGTAGGCACTTGGAT
# 10X_P7_7_TTGTAGGTCATGTAGC        Singlet  10X_P7_7_TTGTAGGTCATGTAGC
# 10X_P7_7_TTTACTGGTGTTGAGG        Singlet  10X_P7_7_TTTACTGGTGTTGAGG
# 10X_P7_7_TTTCCTCCATACCATG        Singlet  10X_P7_7_TTTCCTCCATACCATG
#
# [2300 rows x 26 columns]

# %%
# df = df.drop(columns='index')
df = df.dropna(axis=1, how='all')
df
# Out:
#                           orig.ident  n_counts  n_genes   channel   tissue  \
# 10X_P4_3_AAAGTAGAGATGCCAG        10X   10291.0     2853  10X_P4_3  Bladder
# 10X_P4_3_AACTCCCGTCGGGTCT        10X   12944.0     3347  10X_P4_3  Bladder
# 10X_P4_3_AACTCTTAGTTGCAGG        10X   19594.0     3851  10X_P4_3  Bladder
# 10X_P4_3_AACTCTTTCATAACCG        10X   14594.0     3809  10X_P4_3  Bladder
# 10X_P4_3_AAGGAGCGTGCAACTT        10X    5005.0     1960  10X_P4_3  Bladder
# ...                              ...       ...      ...       ...      ...
# 10X_P7_7_TTGGAACGTGTCGCTG        10X   50069.0     5641  10X_P7_7  Bladder
# 10X_P7_7_TTGTAGGCACTTGGAT        10X    9666.0     3087  10X_P7_7  Bladder
# 10X_P7_7_TTGTAGGTCATGTAGC        10X   22993.0     4296  10X_P7_7  Bladder
# 10X_P7_7_TTTACTGGTGTTGAGG        10X    8753.0     3005  10X_P7_7  Bladder
# 10X_P7_7_TTTCCTCCATACCATG        10X   14665.0     3778  10X_P7_7  Bladder
#
#                           subtissue mouse.sex mouse.id  percent.ercc  \
# 10X_P4_3_AAAGTAGAGATGCCAG                   M    3-M-8           0.0
# 10X_P4_3_AACTCCCGTCGGGTCT                   M    3-M-8           0.0
# 10X_P4_3_AACTCTTAGTTGCAGG                   M    3-M-8           0.0
# 10X_P4_3_AACTCTTTCATAACCG                   M    3-M-8           0.0
# 10X_P4_3_AAGGAGCGTGCAACTT                   M    3-M-8           0.0
# ...                             ...       ...      ...           ...
# 10X_P7_7_TTGGAACGTGTCGCTG                   F   3-F-56           0.0
# 10X_P7_7_TTGTAGGCACTTGGAT                   F   3-F-56           0.0
# 10X_P7_7_TTGTAGGTCATGTAGC                   F   3-F-56           0.0
# 10X_P7_7_TTTACTGGTGTTGAGG                   F   3-F-56           0.0
# 10X_P7_7_TTTCCTCCATACCATG                   F   3-F-56           0.0
#
#                            percent.ribo  ... cell_ontology_id pct_counts_mt  \
# 10X_P4_3_AAAGTAGAGATGCCAG      0.219609  ...       CL:1001319           0.0
# 10X_P4_3_AACTCCCGTCGGGTCT      0.192444  ...       CL:1001319           0.0
# 10X_P4_3_AACTCTTAGTTGCAGG      0.356385  ...       CL:1001428           0.0
# 10X_P4_3_AACTCTTTCATAACCG      0.157119  ...       CL:1001319           0.0
# 10X_P4_3_AAGGAGCGTGCAACTT      0.190210  ...       CL:1001319           0.0
# ...                                 ...  ...              ...           ...
# 10X_P7_7_TTGGAACGTGTCGCTG      0.400407  ...       CL:1001428           0.0
# 10X_P7_7_TTGTAGGCACTTGGAT      0.108628  ...       CL:0000115           0.0
# 10X_P7_7_TTGTAGGTCATGTAGC      0.286783  ...       CL:1001428           0.0
# 10X_P7_7_TTTACTGGTGTTGAGG      0.120873  ...       CL:1001319           0.0
# 10X_P7_7_TTTCCTCCATACCATG      0.118173  ...       CL:1001319           0.0
#
#                           pct_counts_rb pct_counts_hb percent.plat  \
# 10X_P4_3_AAAGTAGAGATGCCAG           0.0           0.0          0.0
# 10X_P4_3_AACTCCCGTCGGGTCT           0.0           0.0          0.0
# 10X_P4_3_AACTCTTAGTTGCAGG           0.0           0.0          0.0
# 10X_P4_3_AACTCTTTCATAACCG           0.0           0.0          0.0
# 10X_P4_3_AAGGAGCGTGCAACTT           0.0           0.0          0.0
# ...                                 ...           ...          ...
# 10X_P7_7_TTGGAACGTGTCGCTG           0.0           0.0          0.0
# 10X_P7_7_TTGTAGGCACTTGGAT           0.0           0.0          0.0
# 10X_P7_7_TTGTAGGTCATGTAGC           0.0           0.0          0.0
# 10X_P7_7_TTTACTGGTGTTGAGG           0.0           0.0          0.0
# 10X_P7_7_TTTCCTCCATACCATG           0.0           0.0          0.0
#
#                           RNA_snn_res.0.5 seurat_clusters  doublet_score  \
# 10X_P4_3_AAAGTAGAGATGCCAG               6               6       0.110000
# 10X_P4_3_AACTCCCGTCGGGTCT               0               0       0.263333
# 10X_P4_3_AACTCTTAGTTGCAGG               3               3       0.270000
# 10X_P4_3_AACTCTTTCATAACCG               0               0       0.286667
# 10X_P4_3_AAGGAGCGTGCAACTT               6               6       0.063333
# ...                                   ...             ...            ...
# 10X_P7_7_TTGGAACGTGTCGCTG               3               3       0.260000
# 10X_P7_7_TTGTAGGCACTTGGAT               9               9       0.260000
# 10X_P7_7_TTGTAGGTCATGTAGC               7               7       0.240000
# 10X_P7_7_TTTACTGGTGTTGAGG               5               5       0.206667
# 10X_P7_7_TTTCCTCCATACCATG               5               5       0.203333
#
#                            doublet_class                      index
# 10X_P4_3_AAAGTAGAGATGCCAG        Singlet  10X_P4_3_AAAGTAGAGATGCCAG
# 10X_P4_3_AACTCCCGTCGGGTCT        Singlet  10X_P4_3_AACTCCCGTCGGGTCT
# 10X_P4_3_AACTCTTAGTTGCAGG        Singlet  10X_P4_3_AACTCTTAGTTGCAGG
# 10X_P4_3_AACTCTTTCATAACCG        Singlet  10X_P4_3_AACTCTTTCATAACCG
# 10X_P4_3_AAGGAGCGTGCAACTT        Singlet  10X_P4_3_AAGGAGCGTGCAACTT
# ...                                  ...                        ...
# 10X_P7_7_TTGGAACGTGTCGCTG        Singlet  10X_P7_7_TTGGAACGTGTCGCTG
# 10X_P7_7_TTGTAGGCACTTGGAT        Singlet  10X_P7_7_TTGTAGGCACTTGGAT
# 10X_P7_7_TTGTAGGTCATGTAGC        Singlet  10X_P7_7_TTGTAGGTCATGTAGC
# 10X_P7_7_TTTACTGGTGTTGAGG        Singlet  10X_P7_7_TTTACTGGTGTTGAGG
# 10X_P7_7_TTTCCTCCATACCATG        Singlet  10X_P7_7_TTTCCTCCATACCATG
#
# [2300 rows x 26 columns]

# %%
def regularise_df(df):
    df = df.dropna(axis=1, how='all')
    res = df
    for col in df.columns:
        if len(df[col].unique()) == 1:
                res = res.drop(col,axis=1)
    return res

# %%
df = regularise_df(df)
df
# Out:
#                            n_counts  n_genes   channel mouse.sex mouse.id  \
# 10X_P4_3_AAAGTAGAGATGCCAG   10291.0     2853  10X_P4_3         M    3-M-8
# 10X_P4_3_AACTCCCGTCGGGTCT   12944.0     3347  10X_P4_3         M    3-M-8
# 10X_P4_3_AACTCTTAGTTGCAGG   19594.0     3851  10X_P4_3         M    3-M-8
# 10X_P4_3_AACTCTTTCATAACCG   14594.0     3809  10X_P4_3         M    3-M-8
# 10X_P4_3_AAGGAGCGTGCAACTT    5005.0     1960  10X_P4_3         M    3-M-8
# ...                             ...      ...       ...       ...      ...
# 10X_P7_7_TTGGAACGTGTCGCTG   50069.0     5641  10X_P7_7         F   3-F-56
# 10X_P7_7_TTGTAGGCACTTGGAT    9666.0     3087  10X_P7_7         F   3-F-56
# 10X_P7_7_TTGTAGGTCATGTAGC   22993.0     4296  10X_P7_7         F   3-F-56
# 10X_P7_7_TTTACTGGTGTTGAGG    8753.0     3005  10X_P7_7         F   3-F-56
# 10X_P7_7_TTTCCTCCATACCATG   14665.0     3778  10X_P7_7         F   3-F-56
#
#                            percent.ribo                  free_annotation  \
# 10X_P4_3_AAAGTAGAGATGCCAG      0.219609         Bladder mesenchymal cell
# 10X_P4_3_AACTCCCGTCGGGTCT      0.192444         Bladder mesenchymal cell
# 10X_P4_3_AACTCTTAGTTGCAGG      0.356385  Luminal bladder epithelial cell
# 10X_P4_3_AACTCTTTCATAACCG      0.157119         Bladder mesenchymal cell
# 10X_P4_3_AAGGAGCGTGCAACTT      0.190210         Bladder mesenchymal cell
# ...                                 ...                              ...
# 10X_P7_7_TTGGAACGTGTCGCTG      0.400407  Luminal bladder epithelial cell
# 10X_P7_7_TTGTAGGCACTTGGAT      0.108628                              NaN
# 10X_P7_7_TTGTAGGTCATGTAGC      0.286783    Basal bladder epithelial cell
# 10X_P7_7_TTTACTGGTGTTGAGG      0.120873         Bladder mesenchymal cell
# 10X_P7_7_TTTCCTCCATACCATG      0.118173         Bladder mesenchymal cell
#
#                                cell_ontology_class res.0.4 cluster.ids  \
# 10X_P4_3_AAAGTAGAGATGCCAG             bladder cell       0           0
# 10X_P4_3_AACTCCCGTCGGGTCT             bladder cell       5           5
# 10X_P4_3_AACTCTTAGTTGCAGG  bladder urothelial cell       3           3
# 10X_P4_3_AACTCTTTCATAACCG             bladder cell       2           2
# 10X_P4_3_AAGGAGCGTGCAACTT             bladder cell       0           0
# ...                                            ...     ...         ...
# 10X_P7_7_TTGGAACGTGTCGCTG  bladder urothelial cell       4           4
# 10X_P7_7_TTGTAGGCACTTGGAT         endothelial cell       7           7
# 10X_P7_7_TTGTAGGTCATGTAGC  bladder urothelial cell       1           1
# 10X_P7_7_TTTACTGGTGTTGAGG             bladder cell       5           5
# 10X_P7_7_TTTCCTCCATACCATG             bladder cell       5           5
#
#                           cell_ontology_id RNA_snn_res.0.5 seurat_clusters  \
# 10X_P4_3_AAAGTAGAGATGCCAG       CL:1001319               6               6
# 10X_P4_3_AACTCCCGTCGGGTCT       CL:1001319               0               0
# 10X_P4_3_AACTCTTAGTTGCAGG       CL:1001428               3               3
# 10X_P4_3_AACTCTTTCATAACCG       CL:1001319               0               0
# 10X_P4_3_AAGGAGCGTGCAACTT       CL:1001319               6               6
# ...                                    ...             ...             ...
# 10X_P7_7_TTGGAACGTGTCGCTG       CL:1001428               3               3
# 10X_P7_7_TTGTAGGCACTTGGAT       CL:0000115               9               9
# 10X_P7_7_TTGTAGGTCATGTAGC       CL:1001428               7               7
# 10X_P7_7_TTTACTGGTGTTGAGG       CL:1001319               5               5
# 10X_P7_7_TTTCCTCCATACCATG       CL:1001319               5               5
#
#                            doublet_score                      index
# 10X_P4_3_AAAGTAGAGATGCCAG       0.110000  10X_P4_3_AAAGTAGAGATGCCAG
# 10X_P4_3_AACTCCCGTCGGGTCT       0.263333  10X_P4_3_AACTCCCGTCGGGTCT
# 10X_P4_3_AACTCTTAGTTGCAGG       0.270000  10X_P4_3_AACTCTTAGTTGCAGG
# 10X_P4_3_AACTCTTTCATAACCG       0.286667  10X_P4_3_AACTCTTTCATAACCG
# 10X_P4_3_AAGGAGCGTGCAACTT       0.063333  10X_P4_3_AAGGAGCGTGCAACTT
# ...                                  ...                        ...
# 10X_P7_7_TTGGAACGTGTCGCTG       0.260000  10X_P7_7_TTGGAACGTGTCGCTG
# 10X_P7_7_TTGTAGGCACTTGGAT       0.260000  10X_P7_7_TTGTAGGCACTTGGAT
# 10X_P7_7_TTGTAGGTCATGTAGC       0.240000  10X_P7_7_TTGTAGGTCATGTAGC
# 10X_P7_7_TTTACTGGTGTTGAGG       0.206667  10X_P7_7_TTTACTGGTGTTGAGG
# 10X_P7_7_TTTCCTCCATACCATG       0.203333  10X_P7_7_TTTCCTCCATACCATG
#
# [2300 rows x 15 columns]

# %%
adata.obs_vector('pct_counts_hb').tolist()

# %%
adata.obs['pct_counts_hb'].tolist()

# %%
obs = gzip_df(df)
ungzip_df(obs)

# %%
adata.obs

# %%
adata.obsm['X_umap'].shape

# %%
adata.obs

# %%
adata.obs.shape

# %%
import json_numpy
umap = json_numpy.dumps(adata.obsm['X_umap'])
json_numpy.loads(umap).shape

# %%
obs = gzip_df(adata.obs)
obs_unzip = ungzip_df(obs)

# %%
obs_unzip

# %%
obs_unzip.shape

# %%
adata.obs['tissue'].tolist()

# %%
adata.obs.to_json(orient='values')

# %%
len(adata.obs.to_json(orient='values'))

# %%
len(json.dumps(adata.obs.to_dict()))

# %%
adata.var

# %%
norm_dict = sc.pp.normalize_total(adata, target_sum=100, inplace=False)
norm_dict

# %%
mean_percent = norm_dict["X"].mean(axis=0).A1
mean_percent

# %%
top_idx = np.argsort(mean_percent)[::-1][:30]
top_idx

# %%
columns = (
        adata.var_names[top_idx]
    )

counts_top_genes = norm_dict["X"][:, top_idx].A
counts_top_genes.shape

# %%
columns

# %%
columns = adata.var_names[top_idx].to_list()
columns

# %%
counts_top_genes = pd.DataFrame(
        counts_top_genes, columns=columns
    )

# %%
counts_top_genes

# %%
len(adata.obs_names)

# %%
len(json.dumps(adata.obs.to_dict('list')))

# %%
len(gzip_str(json.dumps(counts_top_genes.tolist())))

# %%
len(json_numpy.dumps(counts_top_genes))

# %%
zipDf = gzip_df(adata.obs)

# %%
df = ungzip_df(zipDf)
df

# %%
# 打印JSON字符串
# print("原始json字符串：", jsonStr)
print("原始json字符串长度：", len(df.to_json()))
# zipStr = gzip_str(jsonStr)
# print("压缩编码后的json字符串：", zipStr)
print("压缩编码后的json字符串长度：", len(zipDf))
# unzipStr = ungzip_str(zipStr)
# # print("解压缩后的json字符串：", unzipStr)
# print("解压缩后的json字符串长度：", len(unzipStr))
# if jsonStr == unzipStr:
#     print("源字符串和解压后的字符串相同")
# else:
#     print("源字符串和解压后的字符串不同")

# %%
len(adata.obsm['X_umap'].tolist())

# %%
type(adata.obs)

# %%
adata.obsm['X_umap']

# %%
len(adata.obsm['X_umap'][:, 0])

# %%
len(adata.obsm['X_umap'][0])

# %%
adata.obs.index.values.tolist()

# %%
def df_to_dict(df:pd.DataFrame):
    df_dict = {}
    df_columns = df.columns.values.tolist()
    df_index = df.index.values.tolist()
    df_dict['columns'] = df_columns
    df_dict['index'] = df_index
    
    for name in df_columns:
        df_dict[name] = df[name].tolist()
        
    return df_dict

# %%
obs = df_to_dict(adata.obs)
obs

# %%
obs.keys()

# %%
arr_list = arr_to_list(adata.obsm['X_umap'])
arr_list[0]

# %%
umap_json = json.dumps({'umap': umap})

# %%
len(umap_json)

# %%
umap_zip = gzip_str(umap_json)
len(umap_zip)

# %%
len(ungzip_str(umap_zip))

# %%
adata.obsm['X_umap'].shape

# %%
adata.obsm['X_umap'][0]

# %%
import psutil

# %%
import platform

# %%
platform.processor()
# Out:
# 'x86_64'

# %%
psutil.cpu_count(logical=False)
# Out:
# 28

# %%
psutil.cpu_count()
# Out:
# 56

# %%
psutil.cpu_freq().max / 1000
# Out:
# 3.0

# %%
round(psutil.virtual_memory().total / 1024 / 1024 / 1024, 2)
# Out:
# 251.79

# %%
from pynvml import *
nvidia_dict = {
    "state": True,
    "nvidia_version": "",
    "nvidia_count": 0,
    "gpus": []
}
try:
    nvmlInit()
    nvidia_dict["nvidia_version"] = nvmlSystemGetDriverVersion()
    nvidia_dict["nvidia_count"] = nvmlDeviceGetCount()
    for i in range(nvidia_dict["nvidia_count"]):
        handle = nvmlDeviceGetHandleByIndex(i)
        memory_info = nvmlDeviceGetMemoryInfo(handle)
        gpu = {
            "gpu_name": nvmlDeviceGetName(handle),
            "total": round(memory_info.total / 1024 / 1024 / 1024, 2),
            # "free": round(memory_info.free / 1024 / 1024 / 1024, 2),
            # "used": round(memory_info.used / 1024 / 1024 / 1024, 2),
            # "temperature": f"{nvmlDeviceGetTemperature(handle, 0)}℃",
            # "powerStatus": nvmlDeviceGetPowerState(handle)
        }
        nvidia_dict['gpus'].append(gpu)
except NVMLError as _:
    nvidia_dict["state"] = False
except Exception as _:
    nvidia_dict["state"] = False
finally:
    try:
        nvmlShutdown()
    except:
        pass

print(nvidia_dict)
# Out:
# {'state': False, 'nvidia_version': '', 'nvidia_count': 0, 'gpus': []}

# %%
sysinfo={}
len(sysinfo)
# Out:
# 0

# %%
'GPU' in sysinfo.keys()
# Out:
# False
