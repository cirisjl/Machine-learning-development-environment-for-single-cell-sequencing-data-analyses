# %%
# devtools::install_github("cellgeni/sceasy")

# %%
library(scater)
library(scDblFinder)
library(BiocParallel)
library(SeuratObject)
library(Seurat)
source("../tools/formating/formating.R")
# Out:
# Loading required package: SingleCellExperiment
#
# Loading required package: SummarizedExperiment
#
# Loading required package: MatrixGenerics
#
# Loading required package: matrixStats
#
#
# Attaching package: ‘MatrixGenerics’
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
#
# Loading required package: GenomicRanges
#
# Loading required package: stats4
#
# Loading required package: BiocGenerics
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, intersect, is.unsorted, lapply, Map, mapply,
#     match, mget, order, paste, pmax, pmax.int, pmin, pmin.int,
#     Position, rank, rbind, Reduce, rownames, sapply, setdiff, sort,
#     table, tapply, union, unique, unsplit, which.max, which.min
#
#
# Loading required package: S4Vectors
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Loading required package: IRanges
#
# Loading required package: GenomeInfoDb
#
# Loading required package: Biobase
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
#
# Attaching package: ‘Biobase’
#
#
# The following object is masked from ‘package:MatrixGenerics’:
#
#     rowMedians
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
#
# Loading required package: scuttle
#
# Loading required package: ggplot2
#
# Loading required package: sp
#
#
# Attaching package: ‘sp’
#
#
# The following object is masked from ‘package:IRanges’:
#
#     %over%
#
#
#
# Attaching package: ‘SeuratObject’
#
#
# The following object is masked from ‘package:SummarizedExperiment’:
#
#     Assays
#
#
# The following object is masked from ‘package:GenomicRanges’:
#
#     intersect
#
#
# The following object is masked from ‘package:GenomeInfoDb’:
#
#     intersect
#
#
# The following object is masked from ‘package:IRanges’:
#
#     intersect
#
#
# The following object is masked from ‘package:S4Vectors’:
#
#     intersect
#
#
# The following object is masked from ‘package:BiocGenerics’:
#
#     intersect
#
#
# The following object is masked from ‘package:base’:
#
#     intersect
#
#
#
# Attaching package: ‘Seurat’
#
#
# The following object is masked from ‘package:SummarizedExperiment’:
#
#     Assays
# Error in source("../tools/formating/formating.R"): ../tools/formating/formating.R:519:5: unexpected ')'
# 518:         )
# 519:     )
#          ^
# Traceback:
#
# 1. source("../tools/formating/formating.R")

# %%
# install.packages("SeuratObject")
# remotes::install_version("Seurat", "4.4.0", repos = c("https://satijalab.r-universe.dev", getOption("repos")))

# %%
sessionInfo()

# %%
# path = "/ps/ai-ready/data/tung/umi.h5Seurat"
# path = "/ps/ai-ready/data/Clustering/Tabula_Muris/droplet_Bladder_seurat_tiss.h5ad"
path = "/ps/ai-ready/data/error/droplet_Bladder_seurat_tiss.Robj"
# srat <- LoadSeurat(path)
# srat

# %%
robj <- get(load(path))
robj
# Out:
# An old seurat object
#  23341 genes across 2500 samples

# %%
srat_v3 <- UpdateSeuratObject(robj)
srat_v3
# Out:
# Updating from v2.X to v3.X
#
# Warning message:
# “Not validating Assay objects”
# Warning message:
# “Not validating Assay objects”
# Warning message:
# “Not validating DimReduc objects”
# Warning message:
# “Not validating DimReduc objects”
# Warning message:
# “Not validating DimReduc objects”
# Warning message:
# “Not validating DimReduc objects”
# Warning message:
# “Not validating Seurat objects”
# Warning message:
# “Not validating Seurat objects”
# Warning message:
# “Not validating Seurat objects”
# Validating object structure
#
# Updating object slots
#
# Ensuring keys are in the proper structure
#
# Updating matrix keys for DimReduc ‘pca’
#
# Updating matrix keys for DimReduc ‘tsne’
#
# Ensuring keys are in the proper structure
#
# Ensuring feature names don't have underscores or pipes
#
# Updating slots in RNA
#
# Updating slots in pca
#
# Updating slots in tsne
#
# Setting tsne DimReduc to global
#
# Validating object structure for Assay ‘RNA’
#
# Validating object structure for DimReduc ‘pca’
# Error in validObject(object = object[[i]]): invalid class “DimReduc” object: 'global' must be a 1-length logical
# Traceback:
#
# 1. UpdateSeuratObject(robj)
# 2. validObject(object = object[[i]])
# 3. stop(msg, ": ", errors, domain = NA)

# %%
# Return metadata and a list of assays if the default assay is not "RNA"
GetMetadataFromSeurat <- function(path, assay='RNA') {
    srat <- LoadSeurat(path)
    default_assay <- NULL
    assay_names <- NULL
    metadata <- NULL
    HVGsID <- NULL
    nGenes <- 0
    nCells <- 0
    genes <- NULL
    cells <- NULL
    pca <- NULL
    tsne <- NULL
    umap <- NULL
    info <- NULL
    # suffix <- tolower(GetSuffix(path))

    if(!is.null(srat)){
        assay_names <- names(srat@assays)
        if(assay != 'RNA' && assay %in% assay_names){
            DefaultAssay(srat) <- assay
        }
        else if(!(assay %in% assay_names)){
            assay <- DefaultAssay(srat)
        }
        default_assay <- DefaultAssay(srat)
        metadata <- srat@meta.data
        nCells <- ncol(srat)
        nGenes <- nrow(srat)
        genes <- rownames(srat)
        cells <- Cells(srat)
        HVGsID <- srat[[assay]]@var.features
        if('pca' %in% names(srat@reductions)) pca <- Embeddings(object = srat, reduction = "pca")
        if('tsne' %in% names(srat@reductions)) tsne <- Embeddings(object = srat, reduction = "tsne")
        if('umap' %in% names(srat@reductions)) umap <- Embeddings(object = srat, reduction = "umap")
        info <- print(srat)
    }
    srat <- NULL
    
    list(default_assay=default_assay, assay_names=assay_names, metadata=metadata, nCells=nCells, nGenes=nGenes, genes=genes, cells=cells, HVGsID=HVGsID, pca=pca, tsne=tsne, umap=umap, info=info)
}

# %%
results <- GetMetadataFromSeurat(path)
print(results$info)
# Out:
# [1] "Inside LoadSeurat"
# Validating h5Seurat file
#
# Initializing ERCC with data
#
# Adding counts for ERCC
#
# Adding miscellaneous information for ERCC
#
# Initializing originalexp with data
#
# Adding counts for originalexp
#
# Adding feature-level metadata for originalexp
#
# Adding miscellaneous information for originalexp
#
# Adding command information
#
# Adding cell-level metadata
#
# Adding miscellaneous information
#
# Adding tool-specific results
# An object of class Seurat
# 18167 features across 864 samples within 2 assays
# Active assay: ERCC (89 features, 0 variable features)
#  2 layers present: counts, data
#  1 other assay present: originalexp
# $default_assay
# [1] "ERCC"
#
# $assay_names
# [1] "ERCC"        "originalexp"
#
# $metadata
#                nCount_originalexp nFeature_originalexp    orig.ident individual
# NA19098.r1.A01              61707                 8242 SeuratProject    NA19098
# NA19098.r1.A02              62300                 8115 SeuratProject    NA19098
# NA19098.r1.A03              42212                 7189 SeuratProject    NA19098
# NA19098.r1.A04              52324                 7863 SeuratProject    NA19098
# NA19098.r1.A05              69192                 8494 SeuratProject    NA19098
# NA19098.r1.A06              66341                 8535 SeuratProject    NA19098
# NA19098.r1.A07              56514                 7926 SeuratProject    NA19098
# NA19098.r1.A08              87280                 9284 SeuratProject    NA19098
# NA19098.r1.A09              58442                 8122 SeuratProject    NA19098
# NA19098.r1.A10              85571                 9259 SeuratProject    NA19098
# NA19098.r1.A11              71737                 8701 SeuratProject    NA19098
# NA19098.r1.A12              84727                 9040 SeuratProject    NA19098
# NA19098.r1.B01              92493                 9188 SeuratProject    NA19098
# NA19098.r1.B02              63199                 8385 SeuratProject    NA19098
# NA19098.r1.B03              68637                 8680 SeuratProject    NA19098
# NA19098.r1.B04              68012                 8489 SeuratProject    NA19098
# NA19098.r1.B05              93034                 9389 SeuratProject    NA19098
# NA19098.r1.B06              76416                 8894 SeuratProject    NA19098
# NA19098.r1.B07              85383                 9037 SeuratProject    NA19098
# NA19098.r1.B08              97579                 9670 SeuratProject    NA19098
# NA19098.r1.B09              62120                 8477 SeuratProject    NA19098
# NA19098.r1.B10              25981                 6050 SeuratProject    NA19098
# NA19098.r1.B11              58502                 8173 SeuratProject    NA19098
# NA19098.r1.B12              95363                 9431 SeuratProject    NA19098
# NA19098.r1.C01              78010                 8870 SeuratProject    NA19098
# NA19098.r1.C02              90024                 9235 SeuratProject    NA19098
# NA19098.r1.C03              72816                 8654 SeuratProject    NA19098
# NA19098.r1.C04              67485                 8403 SeuratProject    NA19098
# NA19098.r1.C05              81912                 8967 SeuratProject    NA19098
# NA19098.r1.C06              90878                 9376 SeuratProject    NA19098
# NA19098.r1.C07              70795                 8631 SeuratProject    NA19098
# NA19098.r1.C08              57943                 8025 SeuratProject    NA19098
# NA19098.r1.C09              74057                 8770 SeuratProject    NA19098
# NA19098.r1.C10              85615                 9030 SeuratProject    NA19098
# NA19098.r1.C11             100462                 9546 SeuratProject    NA19098
# NA19098.r1.C12              66421                 8570 SeuratProject    NA19098
# NA19098.r1.D01              68695                 8438 SeuratProject    NA19098
# NA19098.r1.D02              83344                 9139 SeuratProject    NA19098
# NA19098.r1.D03              84025                 9003 SeuratProject    NA19098
# NA19098.r1.D04              85200                 9125 SeuratProject    NA19098
# NA19098.r1.D05              43376                 7165 SeuratProject    NA19098
# NA19098.r1.D06              86763                 9111 SeuratProject    NA19098
# NA19098.r1.D07              41358                 7364 SeuratProject    NA19098
# NA19098.r1.D08              84571                 9165 SeuratProject    NA19098
# NA19098.r1.D09              64641                 8370 SeuratProject    NA19098
# NA19098.r1.D10              81993                 9063 SeuratProject    NA19098
# NA19098.r1.D11              52660                 7759 SeuratProject    NA19098
# NA19098.r1.D12              86170                 8961 SeuratProject    NA19098
# NA19098.r1.E01              80282                 8888 SeuratProject    NA19098
# NA19098.r1.E02              87960                 9190 SeuratProject    NA19098
# NA19098.r1.E03              97349                 9340 SeuratProject    NA19098
# NA19098.r1.E04              15314                 4657 SeuratProject    NA19098
# NA19098.r1.E05              53682                 7735 SeuratProject    NA19098
# NA19098.r1.E06              86961                 9186 SeuratProject    NA19098
# NA19098.r1.E07              76439                 8862 SeuratProject    NA19098
# NA19098.r1.E08              97245                 9395 SeuratProject    NA19098
# NA19098.r1.E09              81496                 9066 SeuratProject    NA19098
# NA19098.r1.E10              87300                 9100 SeuratProject    NA19098
# NA19098.r1.E11              96319                 9290 SeuratProject    NA19098
# NA19098.r1.E12              59169                 8097 SeuratProject    NA19098
# NA19098.r1.F01              94037                 9837 SeuratProject    NA19098
# NA19098.r1.F02              92981                 9269 SeuratProject    NA19098
# NA19098.r1.F03              89792                 9124 SeuratProject    NA19098
# NA19098.r1.F04              38235                 6906 SeuratProject    NA19098
# NA19098.r1.F05              31855                 6717 SeuratProject    NA19098
# NA19098.r1.F06              42980                 7319 SeuratProject    NA19098
# NA19098.r1.F07              54800                 7943 SeuratProject    NA19098
# NA19098.r1.F08              68778                 8576 SeuratProject    NA19098
# NA19098.r1.F09              66123                 8389 SeuratProject    NA19098
# NA19098.r1.F10              87097                 8999 SeuratProject    NA19098
# NA19098.r1.F11              81431                 8929 SeuratProject    NA19098
# NA19098.r1.F12              79832                 9025 SeuratProject    NA19098
# NA19098.r1.G01              67186                 8430 SeuratProject    NA19098
# NA19098.r1.G02              62247                 8262 SeuratProject    NA19098
# NA19098.r1.G03              68976                 8610 SeuratProject    NA19098
# NA19098.r1.G04              81902                 8960 SeuratProject    NA19098
# NA19098.r1.G05              89669                 9206 SeuratProject    NA19098
# NA19098.r1.G06              77290                 8829 SeuratProject    NA19098
# NA19098.r1.G07              78351                 9016 SeuratProject    NA19098
# NA19098.r1.G08              54344                 7916 SeuratProject    NA19098
# NA19098.r1.G09              68295                 8577 SeuratProject    NA19098
# NA19098.r1.G10              68267                 8468 SeuratProject    NA19098
# NA19098.r1.G11              78446                 8809 SeuratProject    NA19098
# NA19098.r1.G12              62403                 8171 SeuratProject    NA19098
# NA19098.r1.H01              75486                 8699 SeuratProject    NA19098
# NA19098.r1.H02              67943                 8581 SeuratProject    NA19098
# NA19098.r1.H03              71038                 8764 SeuratProject    NA19098
# NA19098.r1.H04              75040                 8690 SeuratProject    NA19098
# NA19098.r1.H05              90262                 9039 SeuratProject    NA19098
# NA19098.r1.H06              47972                 7687 SeuratProject    NA19098
# NA19098.r1.H07              66489                 8537 SeuratProject    NA19098
# NA19098.r1.H08              28456                 6476 SeuratProject    NA19098
# NA19098.r1.H09              17960                 4984 SeuratProject    NA19098
# NA19098.r1.H10              61441                 8213 SeuratProject    NA19098
# NA19098.r1.H11              90011                 9252 SeuratProject    NA19098
# NA19098.r1.H12              53509                 7822 SeuratProject    NA19098
# NA19098.r2.A01              38378                 7212 SeuratProject    NA19098
# NA19098.r2.A02              94607                 9508 SeuratProject    NA19098
# NA19098.r2.A03              94853                 9443 SeuratProject    NA19098
# NA19098.r2.A04              70048                 8656 SeuratProject    NA19098
# NA19098.r2.A05              94566                 9346 SeuratProject    NA19098
# NA19098.r2.A06              35005                 6989 SeuratProject    NA19098
# NA19098.r2.A07              84790                 9123 SeuratProject    NA19098
# NA19098.r2.A08              68560                 8676 SeuratProject    NA19098
# NA19098.r2.A09              37358                 7245 SeuratProject    NA19098
# NA19098.r2.A10              72148                 8676 SeuratProject    NA19098
# NA19098.r2.A11              72795                 8906 SeuratProject    NA19098
# NA19098.r2.A12              29568                 6513 SeuratProject    NA19098
# NA19098.r2.B01              31945                 6730 SeuratProject    NA19098
# NA19098.r2.B02             103416                 9528 SeuratProject    NA19098
# NA19098.r2.B03             116205                 9844 SeuratProject    NA19098
# NA19098.r2.B04              68393                 8600 SeuratProject    NA19098
# NA19098.r2.B05              77406                 8976 SeuratProject    NA19098
# NA19098.r2.B06              82390                 9068 SeuratProject    NA19098
# NA19098.r2.B07              70413                 8783 SeuratProject    NA19098
# NA19098.r2.B08              79178                 8923 SeuratProject    NA19098
# NA19098.r2.B09              75207                 8872 SeuratProject    NA19098
# NA19098.r2.B10              82407                 8929 SeuratProject    NA19098
# NA19098.r2.B11              37264                 7223 SeuratProject    NA19098
# NA19098.r2.B12              23222                 5989 SeuratProject    NA19098
# NA19098.r2.C01              73475                 8830 SeuratProject    NA19098
# NA19098.r2.C02              71785                 8782 SeuratProject    NA19098
# NA19098.r2.C03              77422                 9021 SeuratProject    NA19098
# NA19098.r2.C04              28262                 6574 SeuratProject    NA19098
# NA19098.r2.C05              66973                 8641 SeuratProject    NA19098
# NA19098.r2.C06              75891                 8963 SeuratProject    NA19098
# NA19098.r2.C07              64870                 8422 SeuratProject    NA19098
# NA19098.r2.C08              64181                 8520 SeuratProject    NA19098
# NA19098.r2.C09              39517                 7364 SeuratProject    NA19098
# NA19098.r2.C10              64900                 8537 SeuratProject    NA19098
# NA19098.r2.C11              68499                 8655 SeuratProject    NA19098
# NA19098.r2.C12              63750                 8325 SeuratProject    NA19098
# NA19098.r2.D01              61467                 8307 SeuratProject    NA19098
# NA19098.r2.D02              50329                 7914 SeuratProject    NA19098
# NA19098.r2.D03              62957                 8531 SeuratProject    NA19098
# NA19098.r2.D04              73264                 8813 SeuratProject    NA19098
# NA19098.r2.D05              74050                 8698 SeuratProject    NA19098
# NA19098.r2.D06              74249                 8855 SeuratProject    NA19098
# NA19098.r2.D07              69871                 8707 SeuratProject    NA19098
# NA19098.r2.D08              72732                 8682 SeuratProject    NA19098
# NA19098.r2.D09              30035                 6471 SeuratProject    NA19098
# NA19098.r2.D10              75894                 8914 SeuratProject    NA19098
# NA19098.r2.D11              76953                 8968 SeuratProject    NA19098
# NA19098.r2.D12              74668                 8788 SeuratProject    NA19098
# NA19098.r2.E01              82236                 8916 SeuratProject    NA19098
# NA19098.r2.E02              91260                 9269 SeuratProject    NA19098
# NA19098.r2.E03             102167                 9554 SeuratProject    NA19098
# NA19098.r2.E04              32969                 6800 SeuratProject    NA19098
# NA19098.r2.E05              64039                 8400 SeuratProject    NA19098
# NA19098.r2.E06              69057                 8499 SeuratProject    NA19098
# NA19098.r2.E07              49174                 7559 SeuratProject    NA19098
# NA19098.r2.E08              86376                 9127 SeuratProject    NA19098
# NA19098.r2.E09              72917                 8721 SeuratProject    NA19098
# NA19098.r2.E10             151619                10334 SeuratProject    NA19098
# NA19098.r2.E11              87481                 9172 SeuratProject    NA19098
# NA19098.r2.E12              66671                 8586 SeuratProject    NA19098
# NA19098.r2.F01              38633                 7253 SeuratProject    NA19098
# NA19098.r2.F02              98762                 9480 SeuratProject    NA19098
# NA19098.r2.F03              96326                 9308 SeuratProject    NA19098
# NA19098.r2.F04              81694                 9141 SeuratProject    NA19098
# NA19098.r2.F05              83112                 9104 SeuratProject    NA19098
# NA19098.r2.F06             143042                10291 SeuratProject    NA19098
# NA19098.r2.F07              74150                 8778 SeuratProject    NA19098
# NA19098.r2.F08              71227                 8558 SeuratProject    NA19098
# NA19098.r2.F09              64755                 8363 SeuratProject    NA19098
# NA19098.r2.F10              68898                 8607 SeuratProject    NA19098
# NA19098.r2.F11              34086                 6919 SeuratProject    NA19098
# NA19098.r2.F12              79854                 8985 SeuratProject    NA19098
# NA19098.r2.G01              43371                 7474 SeuratProject    NA19098
# NA19098.r2.G02              92307                 9393 SeuratProject    NA19098
# NA19098.r2.G03              89413                 9321 SeuratProject    NA19098
# NA19098.r2.G04              84295                 9037 SeuratProject    NA19098
# NA19098.r2.G05              45749                 7555 SeuratProject    NA19098
# NA19098.r2.G06              70935                 8821 SeuratProject    NA19098
# NA19098.r2.G07              73945                 8836 SeuratProject    NA19098
# NA19098.r2.G08              76535                 8966 SeuratProject    NA19098
# NA19098.r2.G09              64752                 8432 SeuratProject    NA19098
# NA19098.r2.G10              20375                 5602 SeuratProject    NA19098
# NA19098.r2.G11              49623                 7919 SeuratProject    NA19098
# NA19098.r2.G12             132942                10261 SeuratProject    NA19098
# NA19098.r2.H01              34429                 6861 SeuratProject    NA19098
# NA19098.r2.H02              70761                 8734 SeuratProject    NA19098
# NA19098.r2.H03              75664                 8866 SeuratProject    NA19098
# NA19098.r2.H04              72332                 8775 SeuratProject    NA19098
# NA19098.r2.H05              72001                 8700 SeuratProject    NA19098
# NA19098.r2.H06              76383                 8867 SeuratProject    NA19098
# NA19098.r2.H07              25546                 6206 SeuratProject    NA19098
# NA19098.r2.H08              33612                 6804 SeuratProject    NA19098
# NA19098.r2.H09             101702                 9576 SeuratProject    NA19098
# NA19098.r2.H10              61176                 8269 SeuratProject    NA19098
# NA19098.r2.H11              62448                 8403 SeuratProject    NA19098
# NA19098.r2.H12              33480                 6837 SeuratProject    NA19098
# NA19098.r3.A01             114563                 9771 SeuratProject    NA19098
# NA19098.r3.A02              26336                 6312 SeuratProject    NA19098
# NA19098.r3.A03              79506                 9092 SeuratProject    NA19098
# NA19098.r3.A04             141431                10287 SeuratProject    NA19098
# NA19098.r3.A05              47196                 7706 SeuratProject    NA19098
# NA19098.r3.A06              95495                 9531 SeuratProject    NA19098
# NA19098.r3.A07              36155                 7054 SeuratProject    NA19098
# NA19098.r3.A08              95413                 9501 SeuratProject    NA19098
# NA19098.r3.A09             116418                 9851 SeuratProject    NA19098
# NA19098.r3.A10             101602                 9637 SeuratProject    NA19098
# NA19098.r3.A11             121778                 9895 SeuratProject    NA19098
# NA19098.r3.A12              72270                 8939 SeuratProject    NA19098
# NA19098.r3.B01              48400                 7835 SeuratProject    NA19098
# NA19098.r3.B02              35227                 7001 SeuratProject    NA19098
# NA19098.r3.B03              84769                 9247 SeuratProject    NA19098
# NA19098.r3.B04             109053                 9787 SeuratProject    NA19098
# NA19098.r3.B05             103031                 9634 SeuratProject    NA19098
# NA19098.r3.B06              38972                 7322 SeuratProject    NA19098
# NA19098.r3.B07              82886                 9090 SeuratProject    NA19098
# NA19098.r3.B08              38395                 7210 SeuratProject    NA19098
# NA19098.r3.B09              54316                 8008 SeuratProject    NA19098
# NA19098.r3.B10              92498                 9423 SeuratProject    NA19098
# NA19098.r3.B11             119572                 9881 SeuratProject    NA19098
# NA19098.r3.B12             100349                 9712 SeuratProject    NA19098
# NA19098.r3.C01              83072                 8990 SeuratProject    NA19098
# NA19098.r3.C02              23013                 5956 SeuratProject    NA19098
# NA19098.r3.C03              62824                 8405 SeuratProject    NA19098
# NA19098.r3.C04              92531                 9347 SeuratProject    NA19098
# NA19098.r3.C05              87273                 9245 SeuratProject    NA19098
# NA19098.r3.C06             101856                 9515 SeuratProject    NA19098
# NA19098.r3.C07              36911                 7099 SeuratProject    NA19098
# NA19098.r3.C08              31032                 6800 SeuratProject    NA19098
# NA19098.r3.C09             102474                 9536 SeuratProject    NA19098
# NA19098.r3.C10              79755                 8970 SeuratProject    NA19098
# NA19098.r3.C11             100641                 9508 SeuratProject    NA19098
# NA19098.r3.C12              79046                 8989 SeuratProject    NA19098
# NA19098.r3.D01              30039                 6550 SeuratProject    NA19098
# NA19098.r3.D02              66715                 8821 SeuratProject    NA19098
# NA19098.r3.D03             101666                 9662 SeuratProject    NA19098
# NA19098.r3.D04              25224                 6224 SeuratProject    NA19098
# NA19098.r3.D05              93176                 9452 SeuratProject    NA19098
# NA19098.r3.D06              21797                 5757 SeuratProject    NA19098
# NA19098.r3.D07              70355                 8787 SeuratProject    NA19098
# NA19098.r3.D08             128249                 9944 SeuratProject    NA19098
# NA19098.r3.D09              90474                 9355 SeuratProject    NA19098
# NA19098.r3.D10              85960                 9280 SeuratProject    NA19098
# NA19098.r3.D11              92319                 9444 SeuratProject    NA19098
# NA19098.r3.D12              71086                 8722 SeuratProject    NA19098
# NA19098.r3.E01              99182                 9522 SeuratProject    NA19098
# NA19098.r3.E02              91684                 9365 SeuratProject    NA19098
# NA19098.r3.E03             106333                 9781 SeuratProject    NA19098
# NA19098.r3.E04             100405                 9596 SeuratProject    NA19098
# NA19098.r3.E05              39706                 7376 SeuratProject    NA19098
# NA19098.r3.E06              53571                 8203 SeuratProject    NA19098
# NA19098.r3.E07              95886                 9592 SeuratProject    NA19098
# NA19098.r3.E08              49150                 7767 SeuratProject    NA19098
# NA19098.r3.E09              36964                 6993 SeuratProject    NA19098
# NA19098.r3.E10              80652                 9110 SeuratProject    NA19098
# NA19098.r3.E11              96222                 9472 SeuratProject    NA19098
# NA19098.r3.E12              67882                 8640 SeuratProject    NA19098
# NA19098.r3.F01              36913                 7225 SeuratProject    NA19098
# NA19098.r3.F02             130064                10088 SeuratProject    NA19098
# NA19098.r3.F03              88162                 9259 SeuratProject    NA19098
# NA19098.r3.F04              90219                 9272 SeuratProject    NA19098
# NA19098.r3.F05              99250                 9530 SeuratProject    NA19098
# NA19098.r3.F06              90655                 9187 SeuratProject    NA19098
# NA19098.r3.F07              96665                 9442 SeuratProject    NA19098
# NA19098.r3.F08             120674                 9776 SeuratProject    NA19098
# NA19098.r3.F09              75727                 8871 SeuratProject    NA19098
# NA19098.r3.F10             102106                 9536 SeuratProject    NA19098
# NA19098.r3.F11              47839                 7833 SeuratProject    NA19098
# NA19098.r3.F12              24551                 6114 SeuratProject    NA19098
# NA19098.r3.G01              52189                 7939 SeuratProject    NA19098
# NA19098.r3.G02              43346                 7505 SeuratProject    NA19098
# NA19098.r3.G03              49210                 7772 SeuratProject    NA19098
# NA19098.r3.G04              65574                 8561 SeuratProject    NA19098
# NA19098.r3.G05             117218                 9797 SeuratProject    NA19098
# NA19098.r3.G06              83250                 9106 SeuratProject    NA19098
# NA19098.r3.G07              44468                 7511 SeuratProject    NA19098
# NA19098.r3.G08              57951                 8249 SeuratProject    NA19098
# NA19098.r3.G09              47353                 7703 SeuratProject    NA19098
# NA19098.r3.G10              94571                 9395 SeuratProject    NA19098
# NA19098.r3.G11              30391                 6506 SeuratProject    NA19098
# NA19098.r3.G12              40837                 7303 SeuratProject    NA19098
# NA19098.r3.H01              41819                 7421 SeuratProject    NA19098
# NA19098.r3.H02              93324                 9394 SeuratProject    NA19098
# NA19098.r3.H03             113337                 9876 SeuratProject    NA19098
# NA19098.r3.H04              99094                 9644 SeuratProject    NA19098
# NA19098.r3.H05              95799                 9498 SeuratProject    NA19098
# NA19098.r3.H06              90930                 9302 SeuratProject    NA19098
# NA19098.r3.H07              23106                 5960 SeuratProject    NA19098
# NA19098.r3.H08              29974                 6506 SeuratProject    NA19098
# NA19098.r3.H09              36315                 6908 SeuratProject    NA19098
# NA19098.r3.H10              85140                 9088 SeuratProject    NA19098
# NA19098.r3.H11             101428                 9650 SeuratProject    NA19098
# NA19098.r3.H12              86855                 9227 SeuratProject    NA19098
# NA19101.r1.A01              15956                 4777 SeuratProject    NA19101
# NA19101.r1.A02              68223                 8767 SeuratProject    NA19101
# NA19101.r1.A03              72341                 8805 SeuratProject    NA19101
# NA19101.r1.A04              50100                 7533 SeuratProject    NA19101
# NA19101.r1.A05              70041                 8764 SeuratProject    NA19101
# NA19101.r1.A06              51538                 7927 SeuratProject    NA19101
# NA19101.r1.A07              82780                 9357 SeuratProject    NA19101
# NA19101.r1.A08              51043                 7991 SeuratProject    NA19101
# NA19101.r1.A09              64098                 8426 SeuratProject    NA19101
# NA19101.r1.A10              59523                 8326 SeuratProject    NA19101
# NA19101.r1.A11              38168                 7050 SeuratProject    NA19101
# NA19101.r1.A12              21086                 5668 SeuratProject    NA19101
# NA19101.r1.B01              23787                 5920 SeuratProject    NA19101
# NA19101.r1.B02              50954                 7941 SeuratProject    NA19101
# NA19101.r1.B03              60962                 8323 SeuratProject    NA19101
# NA19101.r1.B04              76973                 8973 SeuratProject    NA19101
# NA19101.r1.B05              62424                 8589 SeuratProject    NA19101
# NA19101.r1.B06              26992                 6397 SeuratProject    NA19101
# NA19101.r1.B07              51937                 7888 SeuratProject    NA19101
# NA19101.r1.B08              46630                 7892 SeuratProject    NA19101
# NA19101.r1.B09              71007                 8697 SeuratProject    NA19101
# NA19101.r1.B10             106625                 9723 SeuratProject    NA19101
# NA19101.r1.B11              59138                 8274 SeuratProject    NA19101
# NA19101.r1.B12              52820                 7976 SeuratProject    NA19101
# NA19101.r1.C01              46034                 7598 SeuratProject    NA19101
# NA19101.r1.C02              52193                 8062 SeuratProject    NA19101
# NA19101.r1.C03              72375                 8775 SeuratProject    NA19101
# NA19101.r1.C04              53832                 7950 SeuratProject    NA19101
# NA19101.r1.C05              54583                 8016 SeuratProject    NA19101
# NA19101.r1.C06              78521                 9006 SeuratProject    NA19101
# NA19101.r1.C07              49904                 7825 SeuratProject    NA19101
# NA19101.r1.C08              63689                 8745 SeuratProject    NA19101
# NA19101.r1.C09              60269                 8345 SeuratProject    NA19101
# NA19101.r1.C10              59799                 8289 SeuratProject    NA19101
# NA19101.r1.C11              57563                 8274 SeuratProject    NA19101
# NA19101.r1.C12              46898                 7612 SeuratProject    NA19101
# NA19101.r1.D01              47741                 7707 SeuratProject    NA19101
# NA19101.r1.D02              59356                 8246 SeuratProject    NA19101
# NA19101.r1.D03              77497                 9082 SeuratProject    NA19101
# NA19101.r1.D04              39137                 7091 SeuratProject    NA19101
# NA19101.r1.D05              51412                 7799 SeuratProject    NA19101
# NA19101.r1.D06              56327                 8183 SeuratProject    NA19101
# NA19101.r1.D07              66130                 8579 SeuratProject    NA19101
# NA19101.r1.D08              76931                 9103 SeuratProject    NA19101
# NA19101.r1.D09              77726                 9090 SeuratProject    NA19101
# NA19101.r1.D10              67480                 8655 SeuratProject    NA19101
# NA19101.r1.D11              80716                 9019 SeuratProject    NA19101
# NA19101.r1.D12              57940                 8144 SeuratProject    NA19101
# NA19101.r1.E01              83294                 9309 SeuratProject    NA19101
# NA19101.r1.E02              50676                 7859 SeuratProject    NA19101
# NA19101.r1.E03              76707                 8957 SeuratProject    NA19101
# NA19101.r1.E04              78600                 8985 SeuratProject    NA19101
# NA19101.r1.E05              41206                 7395 SeuratProject    NA19101
# NA19101.r1.E06              40524                 7305 SeuratProject    NA19101
# NA19101.r1.E07              74547                 8771 SeuratProject    NA19101
# NA19101.r1.E08              50755                 7879 SeuratProject    NA19101
# NA19101.r1.E09              17598                 5132 SeuratProject    NA19101
# NA19101.r1.E10              54622                 7937 SeuratProject    NA19101
# NA19101.r1.E11              18362                 4912 SeuratProject    NA19101
# NA19101.r1.E12              62199                 8380 SeuratProject    NA19101
# NA19101.r1.F01              72022                 8874 SeuratProject    NA19101
# NA19101.r1.F02              93158                 9392 SeuratProject    NA19101
# NA19101.r1.F03              83319                 9140 SeuratProject    NA19101
# NA19101.r1.F04              67134                 8621 SeuratProject    NA19101
# NA19101.r1.F05              17614                 4962 SeuratProject    NA19101
# NA19101.r1.F06             121837                 9924 SeuratProject    NA19101
# NA19101.r1.F07              74207                 8881 SeuratProject    NA19101
# NA19101.r1.F08              81187                 8987 SeuratProject    NA19101
# NA19101.r1.F09              73809                 8818 SeuratProject    NA19101
# NA19101.r1.F10              19693                 5304 SeuratProject    NA19101
# NA19101.r1.F11              53521                 7954 SeuratProject    NA19101
# NA19101.r1.F12              60465                 8355 SeuratProject    NA19101
# NA19101.r1.G01              30406                 6583 SeuratProject    NA19101
# NA19101.r1.G02              57191                 8268 SeuratProject    NA19101
# NA19101.r1.G03              62570                 8474 SeuratProject    NA19101
# NA19101.r1.G04              62563                 8396 SeuratProject    NA19101
# NA19101.r1.G05              56678                 8037 SeuratProject    NA19101
# NA19101.r1.G06              26152                 6034 SeuratProject    NA19101
# NA19101.r1.G07              57382                 8165 SeuratProject    NA19101
# NA19101.r1.G08              65688                 8559 SeuratProject    NA19101
# NA19101.r1.G09              60581                 8320 SeuratProject    NA19101
# NA19101.r1.G10              55786                 8092 SeuratProject    NA19101
# NA19101.r1.G11              61928                 8307 SeuratProject    NA19101
# NA19101.r1.G12              75219                 8896 SeuratProject    NA19101
# NA19101.r1.H01              78239                 9127 SeuratProject    NA19101
# NA19101.r1.H02              71547                 8926 SeuratProject    NA19101
# NA19101.r1.H03              66633                 8781 SeuratProject    NA19101
# NA19101.r1.H04              30433                 6433 SeuratProject    NA19101
# NA19101.r1.H05              76436                 8907 SeuratProject    NA19101
# NA19101.r1.H06              78021                 8849 SeuratProject    NA19101
# NA19101.r1.H07             120995                 9790 SeuratProject    NA19101
# NA19101.r1.H08              57067                 8116 SeuratProject    NA19101
# NA19101.r1.H09              17305                 5083 SeuratProject    NA19101
# NA19101.r1.H10              63549                 8347 SeuratProject    NA19101
# NA19101.r1.H11             115444                 9899 SeuratProject    NA19101
# NA19101.r1.H12              47717                 7526 SeuratProject    NA19101
# NA19101.r2.A01              56188                 8388 SeuratProject    NA19101
# NA19101.r2.A02              58179                 8296 SeuratProject    NA19101
# NA19101.r2.A03              23037                 5931 SeuratProject    NA19101
# NA19101.r2.A04              30897                 6866 SeuratProject    NA19101
# NA19101.r2.A05              61224                 8500 SeuratProject    NA19101
# NA19101.r2.A06              51344                 7968 SeuratProject    NA19101
# NA19101.r2.A07              32200                 7052 SeuratProject    NA19101
# NA19101.r2.A08              63373                 8697 SeuratProject    NA19101
# NA19101.r2.A09              66508                 8700 SeuratProject    NA19101
# NA19101.r2.A10              45008                 7687 SeuratProject    NA19101
# NA19101.r2.A11              24850                 6236 SeuratProject    NA19101
# NA19101.r2.A12              22277                 6150 SeuratProject    NA19101
# NA19101.r2.B01              30857                 7011 SeuratProject    NA19101
# NA19101.r2.B02              74289                 9029 SeuratProject    NA19101
# NA19101.r2.B03              61802                 8443 SeuratProject    NA19101
# NA19101.r2.B04              37337                 7537 SeuratProject    NA19101
# NA19101.r2.B05              35377                 7255 SeuratProject    NA19101
# NA19101.r2.B06              65390                 8709 SeuratProject    NA19101
# NA19101.r2.B07              20884                 5803 SeuratProject    NA19101
# NA19101.r2.B08              41852                 7404 SeuratProject    NA19101
# NA19101.r2.B09              67302                 8684 SeuratProject    NA19101
# NA19101.r2.B10              48512                 7776 SeuratProject    NA19101
# NA19101.r2.B11              27488                 6309 SeuratProject    NA19101
# NA19101.r2.B12              66762                 8631 SeuratProject    NA19101
# NA19101.r2.C01              41851                 7744 SeuratProject    NA19101
# NA19101.r2.C02              29124                 6801 SeuratProject    NA19101
# NA19101.r2.C03              46530                 7760 SeuratProject    NA19101
# NA19101.r2.C04              49834                 7856 SeuratProject    NA19101
# NA19101.r2.C05              52055                 8090 SeuratProject    NA19101
# NA19101.r2.C06              65407                 8393 SeuratProject    NA19101
# NA19101.r2.C07              60073                 8220 SeuratProject    NA19101
# NA19101.r2.C08              53155                 8012 SeuratProject    NA19101
# NA19101.r2.C09              42196                 7834 SeuratProject    NA19101
# NA19101.r2.C10              20162                 5555 SeuratProject    NA19101
# NA19101.r2.C11              60475                 8420 SeuratProject    NA19101
# NA19101.r2.C12              27159                 6322 SeuratProject    NA19101
# NA19101.r2.D01              38550                 7118 SeuratProject    NA19101
# NA19101.r2.D02              49320                 8084 SeuratProject    NA19101
# NA19101.r2.D03              51396                 7965 SeuratProject    NA19101
# NA19101.r2.D04              70485                 8791 SeuratProject    NA19101
# NA19101.r2.D05              35618                 7280 SeuratProject    NA19101
# NA19101.r2.D06              53535                 8139 SeuratProject    NA19101
# NA19101.r2.D07             134197                10354 SeuratProject    NA19101
# NA19101.r2.D08              85553                 9337 SeuratProject    NA19101
# NA19101.r2.D09              46796                 8235 SeuratProject    NA19101
# NA19101.r2.D10              61624                 8566 SeuratProject    NA19101
# NA19101.r2.D11              47545                 7710 SeuratProject    NA19101
# NA19101.r2.D12              33340                 6902 SeuratProject    NA19101
# NA19101.r2.E01              79158                 9195 SeuratProject    NA19101
# NA19101.r2.E02              66493                 8458 SeuratProject    NA19101
# NA19101.r2.E03              50137                 8055 SeuratProject    NA19101
# NA19101.r2.E04              76401                 8830 SeuratProject    NA19101
# NA19101.r2.E05              27335                 6446 SeuratProject    NA19101
# NA19101.r2.E06              67077                 8900 SeuratProject    NA19101
# NA19101.r2.E07              70250                 8940 SeuratProject    NA19101
# NA19101.r2.E08             176862                10590 SeuratProject    NA19101
# NA19101.r2.E09              61595                 8674 SeuratProject    NA19101
# NA19101.r2.E10              69938                 8742 SeuratProject    NA19101
# NA19101.r2.E11              67526                 8768 SeuratProject    NA19101
# NA19101.r2.E12              58421                 8108 SeuratProject    NA19101
# NA19101.r2.F01              87128                 9285 SeuratProject    NA19101
# NA19101.r2.F02              34564                 7026 SeuratProject    NA19101
# NA19101.r2.F03              86342                 9236 SeuratProject    NA19101
# NA19101.r2.F04              68539                 8713 SeuratProject    NA19101
# NA19101.r2.F05              80420                 9071 SeuratProject    NA19101
# NA19101.r2.F06             100335                 9474 SeuratProject    NA19101
# NA19101.r2.F07              72722                 8973 SeuratProject    NA19101
# NA19101.r2.F08              51301                 8055 SeuratProject    NA19101
# NA19101.r2.F09              44134                 7649 SeuratProject    NA19101
# NA19101.r2.F10              31413                 6750 SeuratProject    NA19101
# NA19101.r2.F11              25314                 6328 SeuratProject    NA19101
# NA19101.r2.F12              45424                 7910 SeuratProject    NA19101
# NA19101.r2.G01              69353                 8848 SeuratProject    NA19101
# NA19101.r2.G02              73324                 9133 SeuratProject    NA19101
# NA19101.r2.G03              67694                 8720 SeuratProject    NA19101
# NA19101.r2.G04              71825                 8819 SeuratProject    NA19101
# NA19101.r2.G05              41673                 7507 SeuratProject    NA19101
# NA19101.r2.G06              33262                 7116 SeuratProject    NA19101
# NA19101.r2.G07              78377                 9155 SeuratProject    NA19101
# NA19101.r2.G08              38577                 7524 SeuratProject    NA19101
# NA19101.r2.G09              69229                 8983 SeuratProject    NA19101
# NA19101.r2.G10              30171                 6754 SeuratProject    NA19101
# NA19101.r2.G11              33124                 7106 SeuratProject    NA19101
# NA19101.r2.G12              74796                 8935 SeuratProject    NA19101
# NA19101.r2.H01              67483                 8761 SeuratProject    NA19101
# NA19101.r2.H02              72072                 9081 SeuratProject    NA19101
# NA19101.r2.H03              83600                 9377 SeuratProject    NA19101
# NA19101.r2.H04              14817                 4788 SeuratProject    NA19101
# NA19101.r2.H05              56840                 8139 SeuratProject    NA19101
# NA19101.r2.H06              73713                 8939 SeuratProject    NA19101
# NA19101.r2.H07              84241                 9268 SeuratProject    NA19101
# NA19101.r2.H08              57195                 8288 SeuratProject    NA19101
# NA19101.r2.H09              37047                 7420 SeuratProject    NA19101
# NA19101.r2.H10              17516                 5081 SeuratProject    NA19101
# NA19101.r2.H11              33767                 6930 SeuratProject    NA19101
# NA19101.r2.H12              23970                 6132 SeuratProject    NA19101
# NA19101.r3.A01              25787                 6367 SeuratProject    NA19101
# NA19101.r3.A02              18979                 5090 SeuratProject    NA19101
# NA19101.r3.A03               7783                 3415 SeuratProject    NA19101
# NA19101.r3.A04             117230                 9639 SeuratProject    NA19101
# NA19101.r3.A05               9725                 3688 SeuratProject    NA19101
# NA19101.r3.A06              50616                 7724 SeuratProject    NA19101
# NA19101.r3.A07              53824                 8236 SeuratProject    NA19101
# NA19101.r3.A08             128516                10018 SeuratProject    NA19101
# NA19101.r3.A09              33533                 6770 SeuratProject    NA19101
# NA19101.r3.A10              71629                 8557 SeuratProject    NA19101
# NA19101.r3.A11              24299                 5892 SeuratProject    NA19101
# NA19101.r3.A12              50447                 7525 SeuratProject    NA19101
# NA19101.r3.B01              64740                 8481 SeuratProject    NA19101
# NA19101.r3.B02              68071                 8657 SeuratProject    NA19101
# NA19101.r3.B03             174206                10651 SeuratProject    NA19101
# NA19101.r3.B04             103408                 9456 SeuratProject    NA19101
# NA19101.r3.B05              17403                 4973 SeuratProject    NA19101
# NA19101.r3.B06              52421                 7902 SeuratProject    NA19101
# NA19101.r3.B07              78543                 8892 SeuratProject    NA19101
# NA19101.r3.B08              55167                 7935 SeuratProject    NA19101
# NA19101.r3.B09              60220                 8197 SeuratProject    NA19101
# NA19101.r3.B10              59650                 8314 SeuratProject    NA19101
# NA19101.r3.B11              62757                 8427 SeuratProject    NA19101
# NA19101.r3.B12              63343                 8340 SeuratProject    NA19101
# NA19101.r3.C01              20327                 5544 SeuratProject    NA19101
# NA19101.r3.C02             186602                10864 SeuratProject    NA19101
# NA19101.r3.C03              64049                 8384 SeuratProject    NA19101
# NA19101.r3.C04              74568                 8751 SeuratProject    NA19101
# NA19101.r3.C05              67020                 8427 SeuratProject    NA19101
# NA19101.r3.C06              51567                 7757 SeuratProject    NA19101
# NA19101.r3.C07             111618                 9485 SeuratProject    NA19101
# NA19101.r3.C08              64093                 8275 SeuratProject    NA19101
# NA19101.r3.C09              14117                 4638 SeuratProject    NA19101
# NA19101.r3.C10              41681                 7364 SeuratProject    NA19101
# NA19101.r3.C11              57995                 8114 SeuratProject    NA19101
# NA19101.r3.C12              18167                 5231 SeuratProject    NA19101
# NA19101.r3.D01              27212                 6056 SeuratProject    NA19101
# NA19101.r3.D02             232929                11027 SeuratProject    NA19101
# NA19101.r3.D03              78870                 8966 SeuratProject    NA19101
# NA19101.r3.D04              17878                 5111 SeuratProject    NA19101
# NA19101.r3.D05             113047                 9732 SeuratProject    NA19101
# NA19101.r3.D06              59196                 8149 SeuratProject    NA19101
# NA19101.r3.D07              18074                 5143 SeuratProject    NA19101
# NA19101.r3.D08             164009                10425 SeuratProject    NA19101
# NA19101.r3.D09              11551                 4358 SeuratProject    NA19101
# NA19101.r3.D10              94074                 9305 SeuratProject    NA19101
# NA19101.r3.D11             175787                10515 SeuratProject    NA19101
# NA19101.r3.D12              52316                 7933 SeuratProject    NA19101
# NA19101.r3.E01              42606                 7301 SeuratProject    NA19101
# NA19101.r3.E02              65335                 8463 SeuratProject    NA19101
# NA19101.r3.E03              67694                 8549 SeuratProject    NA19101
# NA19101.r3.E04              55153                 7966 SeuratProject    NA19101
# NA19101.r3.E05             144467                10255 SeuratProject    NA19101
# NA19101.r3.E06              59522                 8319 SeuratProject    NA19101
# NA19101.r3.E07              61605                 8357 SeuratProject    NA19101
# NA19101.r3.E08              24073                 5725 SeuratProject    NA19101
# NA19101.r3.E09              66419                 8675 SeuratProject    NA19101
# NA19101.r3.E10              34145                 6741 SeuratProject    NA19101
# NA19101.r3.E11              64253                 8487 SeuratProject    NA19101
# NA19101.r3.E12             144031                10241 SeuratProject    NA19101
# NA19101.r3.F01              88343                 9261 SeuratProject    NA19101
# NA19101.r3.F02              63645                 8328 SeuratProject    NA19101
# NA19101.r3.F03              47441                 7598 SeuratProject    NA19101
# NA19101.r3.F04             135145                10058 SeuratProject    NA19101
# NA19101.r3.F05             160149                10364 SeuratProject    NA19101
# NA19101.r3.F06             135914                10054 SeuratProject    NA19101
# NA19101.r3.F07              46775                 7637 SeuratProject    NA19101
# NA19101.r3.F08              60508                 8181 SeuratProject    NA19101
# NA19101.r3.F09              19201                 5248 SeuratProject    NA19101
# NA19101.r3.F10             136752                10279 SeuratProject    NA19101
# NA19101.r3.F11              63591                 8214 SeuratProject    NA19101
# NA19101.r3.F12              62128                 8205 SeuratProject    NA19101
# NA19101.r3.G01              55145                 8146 SeuratProject    NA19101
# NA19101.r3.G02              26247                 6212 SeuratProject    NA19101
# NA19101.r3.G03              58200                 8051 SeuratProject    NA19101
# NA19101.r3.G04             177007                10646 SeuratProject    NA19101
# NA19101.r3.G05              74086                 8758 SeuratProject    NA19101
# NA19101.r3.G06              57787                 8011 SeuratProject    NA19101
# NA19101.r3.G07              61132                 8244 SeuratProject    NA19101
# NA19101.r3.G08              47946                 7708 SeuratProject    NA19101
# NA19101.r3.G09              19259                 5281 SeuratProject    NA19101
# NA19101.r3.G10              45786                 7280 SeuratProject    NA19101
# NA19101.r3.G11              50879                 7705 SeuratProject    NA19101
# NA19101.r3.G12              49071                 7584 SeuratProject    NA19101
# NA19101.r3.H01              24313                 5926 SeuratProject    NA19101
# NA19101.r3.H02              26785                 6329 SeuratProject    NA19101
# NA19101.r3.H03              26039                 6020 SeuratProject    NA19101
# NA19101.r3.H04             192765                10727 SeuratProject    NA19101
# NA19101.r3.H05              72107                 8434 SeuratProject    NA19101
# NA19101.r3.H06             111557                 9787 SeuratProject    NA19101
# NA19101.r3.H07              16407                 5069 SeuratProject    NA19101
# NA19101.r3.H08              53322                 7808 SeuratProject    NA19101
# NA19101.r3.H09              19255                 5294 SeuratProject    NA19101
# NA19101.r3.H10              38173                 6854 SeuratProject    NA19101
# NA19101.r3.H11              38720                 7018 SeuratProject    NA19101
# NA19101.r3.H12             129140                 9896 SeuratProject    NA19101
# NA19239.r1.A01              62647                 8205 SeuratProject    NA19239
# NA19239.r1.A02              36876                 6897 SeuratProject    NA19239
# NA19239.r1.A03              55282                 7911 SeuratProject    NA19239
# NA19239.r1.A04              39429                 7257 SeuratProject    NA19239
# NA19239.r1.A05              63468                 8143 SeuratProject    NA19239
# NA19239.r1.A06              60865                 8202 SeuratProject    NA19239
# NA19239.r1.A07              42237                 7315 SeuratProject    NA19239
# NA19239.r1.A08              50536                 7656 SeuratProject    NA19239
# NA19239.r1.A09              68480                 8505 SeuratProject    NA19239
# NA19239.r1.A10              52522                 7760 SeuratProject    NA19239
# NA19239.r1.A11              43368                 7241 SeuratProject    NA19239
# NA19239.r1.A12              42155                 7405 SeuratProject    NA19239
# NA19239.r1.B01              36917                 7102 SeuratProject    NA19239
# NA19239.r1.B02              73791                 8764 SeuratProject    NA19239
# ...
#  [17] "NA19098.r1.B05" "NA19098.r1.B06" "NA19098.r1.B07" "NA19098.r1.B08"
#  [21] "NA19098.r1.B09" "NA19098.r1.B10" "NA19098.r1.B11" "NA19098.r1.B12"
#  [25] "NA19098.r1.C01" "NA19098.r1.C02" "NA19098.r1.C03" "NA19098.r1.C04"
#  [29] "NA19098.r1.C05" "NA19098.r1.C06" "NA19098.r1.C07" "NA19098.r1.C08"
#  [33] "NA19098.r1.C09" "NA19098.r1.C10" "NA19098.r1.C11" "NA19098.r1.C12"
#  [37] "NA19098.r1.D01" "NA19098.r1.D02" "NA19098.r1.D03" "NA19098.r1.D04"
#  [41] "NA19098.r1.D05" "NA19098.r1.D06" "NA19098.r1.D07" "NA19098.r1.D08"
#  [45] "NA19098.r1.D09" "NA19098.r1.D10" "NA19098.r1.D11" "NA19098.r1.D12"
#  [49] "NA19098.r1.E01" "NA19098.r1.E02" "NA19098.r1.E03" "NA19098.r1.E04"
#  [53] "NA19098.r1.E05" "NA19098.r1.E06" "NA19098.r1.E07" "NA19098.r1.E08"
#  [57] "NA19098.r1.E09" "NA19098.r1.E10" "NA19098.r1.E11" "NA19098.r1.E12"
#  [61] "NA19098.r1.F01" "NA19098.r1.F02" "NA19098.r1.F03" "NA19098.r1.F04"
#  [65] "NA19098.r1.F05" "NA19098.r1.F06" "NA19098.r1.F07" "NA19098.r1.F08"
#  [69] "NA19098.r1.F09" "NA19098.r1.F10" "NA19098.r1.F11" "NA19098.r1.F12"
#  [73] "NA19098.r1.G01" "NA19098.r1.G02" "NA19098.r1.G03" "NA19098.r1.G04"
#  [77] "NA19098.r1.G05" "NA19098.r1.G06" "NA19098.r1.G07" "NA19098.r1.G08"
#  [81] "NA19098.r1.G09" "NA19098.r1.G10" "NA19098.r1.G11" "NA19098.r1.G12"
#  [85] "NA19098.r1.H01" "NA19098.r1.H02" "NA19098.r1.H03" "NA19098.r1.H04"
#  [89] "NA19098.r1.H05" "NA19098.r1.H06" "NA19098.r1.H07" "NA19098.r1.H08"
#  [93] "NA19098.r1.H09" "NA19098.r1.H10" "NA19098.r1.H11" "NA19098.r1.H12"
#  [97] "NA19098.r2.A01" "NA19098.r2.A02" "NA19098.r2.A03" "NA19098.r2.A04"
# [101] "NA19098.r2.A05" "NA19098.r2.A06" "NA19098.r2.A07" "NA19098.r2.A08"
# [105] "NA19098.r2.A09" "NA19098.r2.A10" "NA19098.r2.A11" "NA19098.r2.A12"
# [109] "NA19098.r2.B01" "NA19098.r2.B02" "NA19098.r2.B03" "NA19098.r2.B04"
# [113] "NA19098.r2.B05" "NA19098.r2.B06" "NA19098.r2.B07" "NA19098.r2.B08"
# [117] "NA19098.r2.B09" "NA19098.r2.B10" "NA19098.r2.B11" "NA19098.r2.B12"
# [121] "NA19098.r2.C01" "NA19098.r2.C02" "NA19098.r2.C03" "NA19098.r2.C04"
# [125] "NA19098.r2.C05" "NA19098.r2.C06" "NA19098.r2.C07" "NA19098.r2.C08"
# [129] "NA19098.r2.C09" "NA19098.r2.C10" "NA19098.r2.C11" "NA19098.r2.C12"
# [133] "NA19098.r2.D01" "NA19098.r2.D02" "NA19098.r2.D03" "NA19098.r2.D04"
# [137] "NA19098.r2.D05" "NA19098.r2.D06" "NA19098.r2.D07" "NA19098.r2.D08"
# [141] "NA19098.r2.D09" "NA19098.r2.D10" "NA19098.r2.D11" "NA19098.r2.D12"
# [145] "NA19098.r2.E01" "NA19098.r2.E02" "NA19098.r2.E03" "NA19098.r2.E04"
# [149] "NA19098.r2.E05" "NA19098.r2.E06" "NA19098.r2.E07" "NA19098.r2.E08"
# [153] "NA19098.r2.E09" "NA19098.r2.E10" "NA19098.r2.E11" "NA19098.r2.E12"
# [157] "NA19098.r2.F01" "NA19098.r2.F02" "NA19098.r2.F03" "NA19098.r2.F04"
# [161] "NA19098.r2.F05" "NA19098.r2.F06" "NA19098.r2.F07" "NA19098.r2.F08"
# [165] "NA19098.r2.F09" "NA19098.r2.F10" "NA19098.r2.F11" "NA19098.r2.F12"
# [169] "NA19098.r2.G01" "NA19098.r2.G02" "NA19098.r2.G03" "NA19098.r2.G04"
# [173] "NA19098.r2.G05" "NA19098.r2.G06" "NA19098.r2.G07" "NA19098.r2.G08"
# [177] "NA19098.r2.G09" "NA19098.r2.G10" "NA19098.r2.G11" "NA19098.r2.G12"
# [181] "NA19098.r2.H01" "NA19098.r2.H02" "NA19098.r2.H03" "NA19098.r2.H04"
# [185] "NA19098.r2.H05" "NA19098.r2.H06" "NA19098.r2.H07" "NA19098.r2.H08"
# [189] "NA19098.r2.H09" "NA19098.r2.H10" "NA19098.r2.H11" "NA19098.r2.H12"
# [193] "NA19098.r3.A01" "NA19098.r3.A02" "NA19098.r3.A03" "NA19098.r3.A04"
# [197] "NA19098.r3.A05" "NA19098.r3.A06" "NA19098.r3.A07" "NA19098.r3.A08"
# [201] "NA19098.r3.A09" "NA19098.r3.A10" "NA19098.r3.A11" "NA19098.r3.A12"
# [205] "NA19098.r3.B01" "NA19098.r3.B02" "NA19098.r3.B03" "NA19098.r3.B04"
# [209] "NA19098.r3.B05" "NA19098.r3.B06" "NA19098.r3.B07" "NA19098.r3.B08"
# [213] "NA19098.r3.B09" "NA19098.r3.B10" "NA19098.r3.B11" "NA19098.r3.B12"
# [217] "NA19098.r3.C01" "NA19098.r3.C02" "NA19098.r3.C03" "NA19098.r3.C04"
# [221] "NA19098.r3.C05" "NA19098.r3.C06" "NA19098.r3.C07" "NA19098.r3.C08"
# [225] "NA19098.r3.C09" "NA19098.r3.C10" "NA19098.r3.C11" "NA19098.r3.C12"
# [229] "NA19098.r3.D01" "NA19098.r3.D02" "NA19098.r3.D03" "NA19098.r3.D04"
# [233] "NA19098.r3.D05" "NA19098.r3.D06" "NA19098.r3.D07" "NA19098.r3.D08"
# [237] "NA19098.r3.D09" "NA19098.r3.D10" "NA19098.r3.D11" "NA19098.r3.D12"
# [241] "NA19098.r3.E01" "NA19098.r3.E02" "NA19098.r3.E03" "NA19098.r3.E04"
# [245] "NA19098.r3.E05" "NA19098.r3.E06" "NA19098.r3.E07" "NA19098.r3.E08"
# [249] "NA19098.r3.E09" "NA19098.r3.E10" "NA19098.r3.E11" "NA19098.r3.E12"
# [253] "NA19098.r3.F01" "NA19098.r3.F02" "NA19098.r3.F03" "NA19098.r3.F04"
# [257] "NA19098.r3.F05" "NA19098.r3.F06" "NA19098.r3.F07" "NA19098.r3.F08"
# [261] "NA19098.r3.F09" "NA19098.r3.F10" "NA19098.r3.F11" "NA19098.r3.F12"
# [265] "NA19098.r3.G01" "NA19098.r3.G02" "NA19098.r3.G03" "NA19098.r3.G04"
# [269] "NA19098.r3.G05" "NA19098.r3.G06" "NA19098.r3.G07" "NA19098.r3.G08"
# [273] "NA19098.r3.G09" "NA19098.r3.G10" "NA19098.r3.G11" "NA19098.r3.G12"
# [277] "NA19098.r3.H01" "NA19098.r3.H02" "NA19098.r3.H03" "NA19098.r3.H04"
# [281] "NA19098.r3.H05" "NA19098.r3.H06" "NA19098.r3.H07" "NA19098.r3.H08"
# [285] "NA19098.r3.H09" "NA19098.r3.H10" "NA19098.r3.H11" "NA19098.r3.H12"
# [289] "NA19101.r1.A01" "NA19101.r1.A02" "NA19101.r1.A03" "NA19101.r1.A04"
# [293] "NA19101.r1.A05" "NA19101.r1.A06" "NA19101.r1.A07" "NA19101.r1.A08"
# [297] "NA19101.r1.A09" "NA19101.r1.A10" "NA19101.r1.A11" "NA19101.r1.A12"
# [301] "NA19101.r1.B01" "NA19101.r1.B02" "NA19101.r1.B03" "NA19101.r1.B04"
# [305] "NA19101.r1.B05" "NA19101.r1.B06" "NA19101.r1.B07" "NA19101.r1.B08"
# [309] "NA19101.r1.B09" "NA19101.r1.B10" "NA19101.r1.B11" "NA19101.r1.B12"
# [313] "NA19101.r1.C01" "NA19101.r1.C02" "NA19101.r1.C03" "NA19101.r1.C04"
# [317] "NA19101.r1.C05" "NA19101.r1.C06" "NA19101.r1.C07" "NA19101.r1.C08"
# [321] "NA19101.r1.C09" "NA19101.r1.C10" "NA19101.r1.C11" "NA19101.r1.C12"
# [325] "NA19101.r1.D01" "NA19101.r1.D02" "NA19101.r1.D03" "NA19101.r1.D04"
# [329] "NA19101.r1.D05" "NA19101.r1.D06" "NA19101.r1.D07" "NA19101.r1.D08"
# [333] "NA19101.r1.D09" "NA19101.r1.D10" "NA19101.r1.D11" "NA19101.r1.D12"
# [337] "NA19101.r1.E01" "NA19101.r1.E02" "NA19101.r1.E03" "NA19101.r1.E04"
# [341] "NA19101.r1.E05" "NA19101.r1.E06" "NA19101.r1.E07" "NA19101.r1.E08"
# [345] "NA19101.r1.E09" "NA19101.r1.E10" "NA19101.r1.E11" "NA19101.r1.E12"
# [349] "NA19101.r1.F01" "NA19101.r1.F02" "NA19101.r1.F03" "NA19101.r1.F04"
# [353] "NA19101.r1.F05" "NA19101.r1.F06" "NA19101.r1.F07" "NA19101.r1.F08"
# [357] "NA19101.r1.F09" "NA19101.r1.F10" "NA19101.r1.F11" "NA19101.r1.F12"
# [361] "NA19101.r1.G01" "NA19101.r1.G02" "NA19101.r1.G03" "NA19101.r1.G04"
# [365] "NA19101.r1.G05" "NA19101.r1.G06" "NA19101.r1.G07" "NA19101.r1.G08"
# [369] "NA19101.r1.G09" "NA19101.r1.G10" "NA19101.r1.G11" "NA19101.r1.G12"
# [373] "NA19101.r1.H01" "NA19101.r1.H02" "NA19101.r1.H03" "NA19101.r1.H04"
# [377] "NA19101.r1.H05" "NA19101.r1.H06" "NA19101.r1.H07" "NA19101.r1.H08"
# [381] "NA19101.r1.H09" "NA19101.r1.H10" "NA19101.r1.H11" "NA19101.r1.H12"
# [385] "NA19101.r2.A01" "NA19101.r2.A02" "NA19101.r2.A03" "NA19101.r2.A04"
# [389] "NA19101.r2.A05" "NA19101.r2.A06" "NA19101.r2.A07" "NA19101.r2.A08"
# [393] "NA19101.r2.A09" "NA19101.r2.A10" "NA19101.r2.A11" "NA19101.r2.A12"
# [397] "NA19101.r2.B01" "NA19101.r2.B02" "NA19101.r2.B03" "NA19101.r2.B04"
# [401] "NA19101.r2.B05" "NA19101.r2.B06" "NA19101.r2.B07" "NA19101.r2.B08"
# [405] "NA19101.r2.B09" "NA19101.r2.B10" "NA19101.r2.B11" "NA19101.r2.B12"
# [409] "NA19101.r2.C01" "NA19101.r2.C02" "NA19101.r2.C03" "NA19101.r2.C04"
# [413] "NA19101.r2.C05" "NA19101.r2.C06" "NA19101.r2.C07" "NA19101.r2.C08"
# [417] "NA19101.r2.C09" "NA19101.r2.C10" "NA19101.r2.C11" "NA19101.r2.C12"
# [421] "NA19101.r2.D01" "NA19101.r2.D02" "NA19101.r2.D03" "NA19101.r2.D04"
# [425] "NA19101.r2.D05" "NA19101.r2.D06" "NA19101.r2.D07" "NA19101.r2.D08"
# [429] "NA19101.r2.D09" "NA19101.r2.D10" "NA19101.r2.D11" "NA19101.r2.D12"
# [433] "NA19101.r2.E01" "NA19101.r2.E02" "NA19101.r2.E03" "NA19101.r2.E04"
# [437] "NA19101.r2.E05" "NA19101.r2.E06" "NA19101.r2.E07" "NA19101.r2.E08"
# [441] "NA19101.r2.E09" "NA19101.r2.E10" "NA19101.r2.E11" "NA19101.r2.E12"
# [445] "NA19101.r2.F01" "NA19101.r2.F02" "NA19101.r2.F03" "NA19101.r2.F04"
# [449] "NA19101.r2.F05" "NA19101.r2.F06" "NA19101.r2.F07" "NA19101.r2.F08"
# [453] "NA19101.r2.F09" "NA19101.r2.F10" "NA19101.r2.F11" "NA19101.r2.F12"
# [457] "NA19101.r2.G01" "NA19101.r2.G02" "NA19101.r2.G03" "NA19101.r2.G04"
# [461] "NA19101.r2.G05" "NA19101.r2.G06" "NA19101.r2.G07" "NA19101.r2.G08"
# [465] "NA19101.r2.G09" "NA19101.r2.G10" "NA19101.r2.G11" "NA19101.r2.G12"
# [469] "NA19101.r2.H01" "NA19101.r2.H02" "NA19101.r2.H03" "NA19101.r2.H04"
# [473] "NA19101.r2.H05" "NA19101.r2.H06" "NA19101.r2.H07" "NA19101.r2.H08"
# [477] "NA19101.r2.H09" "NA19101.r2.H10" "NA19101.r2.H11" "NA19101.r2.H12"
# [481] "NA19101.r3.A01" "NA19101.r3.A02" "NA19101.r3.A03" "NA19101.r3.A04"
# [485] "NA19101.r3.A05" "NA19101.r3.A06" "NA19101.r3.A07" "NA19101.r3.A08"
# [489] "NA19101.r3.A09" "NA19101.r3.A10" "NA19101.r3.A11" "NA19101.r3.A12"
# [493] "NA19101.r3.B01" "NA19101.r3.B02" "NA19101.r3.B03" "NA19101.r3.B04"
# [497] "NA19101.r3.B05" "NA19101.r3.B06" "NA19101.r3.B07" "NA19101.r3.B08"
# [501] "NA19101.r3.B09" "NA19101.r3.B10" "NA19101.r3.B11" "NA19101.r3.B12"
# [505] "NA19101.r3.C01" "NA19101.r3.C02" "NA19101.r3.C03" "NA19101.r3.C04"
# [509] "NA19101.r3.C05" "NA19101.r3.C06" "NA19101.r3.C07" "NA19101.r3.C08"
# [513] "NA19101.r3.C09" "NA19101.r3.C10" "NA19101.r3.C11" "NA19101.r3.C12"
# [517] "NA19101.r3.D01" "NA19101.r3.D02" "NA19101.r3.D03" "NA19101.r3.D04"
# [521] "NA19101.r3.D05" "NA19101.r3.D06" "NA19101.r3.D07" "NA19101.r3.D08"
# [525] "NA19101.r3.D09" "NA19101.r3.D10" "NA19101.r3.D11" "NA19101.r3.D12"
# [529] "NA19101.r3.E01" "NA19101.r3.E02" "NA19101.r3.E03" "NA19101.r3.E04"
# [533] "NA19101.r3.E05" "NA19101.r3.E06" "NA19101.r3.E07" "NA19101.r3.E08"
# [537] "NA19101.r3.E09" "NA19101.r3.E10" "NA19101.r3.E11" "NA19101.r3.E12"
# [541] "NA19101.r3.F01" "NA19101.r3.F02" "NA19101.r3.F03" "NA19101.r3.F04"
# [545] "NA19101.r3.F05" "NA19101.r3.F06" "NA19101.r3.F07" "NA19101.r3.F08"
# [549] "NA19101.r3.F09" "NA19101.r3.F10" "NA19101.r3.F11" "NA19101.r3.F12"
# [553] "NA19101.r3.G01" "NA19101.r3.G02" "NA19101.r3.G03" "NA19101.r3.G04"
# [557] "NA19101.r3.G05" "NA19101.r3.G06" "NA19101.r3.G07" "NA19101.r3.G08"
# [561] "NA19101.r3.G09" "NA19101.r3.G10" "NA19101.r3.G11" "NA19101.r3.G12"
# [565] "NA19101.r3.H01" "NA19101.r3.H02" "NA19101.r3.H03" "NA19101.r3.H04"
# [569] "NA19101.r3.H05" "NA19101.r3.H06" "NA19101.r3.H07" "NA19101.r3.H08"
# [573] "NA19101.r3.H09" "NA19101.r3.H10" "NA19101.r3.H11" "NA19101.r3.H12"
# [577] "NA19239.r1.A01" "NA19239.r1.A02" "NA19239.r1.A03" "NA19239.r1.A04"
# [581] "NA19239.r1.A05" "NA19239.r1.A06" "NA19239.r1.A07" "NA19239.r1.A08"
# [585] "NA19239.r1.A09" "NA19239.r1.A10" "NA19239.r1.A11" "NA19239.r1.A12"
# [589] "NA19239.r1.B01" "NA19239.r1.B02" "NA19239.r1.B03" "NA19239.r1.B04"
# [593] "NA19239.r1.B05" "NA19239.r1.B06" "NA19239.r1.B07" "NA19239.r1.B08"
# [597] "NA19239.r1.B09" "NA19239.r1.B10" "NA19239.r1.B11" "NA19239.r1.B12"
# [601] "NA19239.r1.C01" "NA19239.r1.C02" "NA19239.r1.C03" "NA19239.r1.C04"
# [605] "NA19239.r1.C05" "NA19239.r1.C06" "NA19239.r1.C07" "NA19239.r1.C08"
# [609] "NA19239.r1.C09" "NA19239.r1.C10" "NA19239.r1.C11" "NA19239.r1.C12"
# [613] "NA19239.r1.D01" "NA19239.r1.D02" "NA19239.r1.D03" "NA19239.r1.D04"
# [617] "NA19239.r1.D05" "NA19239.r1.D06" "NA19239.r1.D07" "NA19239.r1.D08"
# [621] "NA19239.r1.D09" "NA19239.r1.D10" "NA19239.r1.D11" "NA19239.r1.D12"
# [625] "NA19239.r1.E01" "NA19239.r1.E02" "NA19239.r1.E03" "NA19239.r1.E04"
# [629] "NA19239.r1.E05" "NA19239.r1.E06" "NA19239.r1.E07" "NA19239.r1.E08"
# [633] "NA19239.r1.E09" "NA19239.r1.E10" "NA19239.r1.E11" "NA19239.r1.E12"
# [637] "NA19239.r1.F01" "NA19239.r1.F02" "NA19239.r1.F03" "NA19239.r1.F04"
# [641] "NA19239.r1.F05" "NA19239.r1.F06" "NA19239.r1.F07" "NA19239.r1.F08"
# [645] "NA19239.r1.F09" "NA19239.r1.F10" "NA19239.r1.F11" "NA19239.r1.F12"
# [649] "NA19239.r1.G01" "NA19239.r1.G02" "NA19239.r1.G03" "NA19239.r1.G04"
# [653] "NA19239.r1.G05" "NA19239.r1.G06" "NA19239.r1.G07" "NA19239.r1.G08"
# [657] "NA19239.r1.G09" "NA19239.r1.G10" "NA19239.r1.G11" "NA19239.r1.G12"
# [661] "NA19239.r1.H01" "NA19239.r1.H02" "NA19239.r1.H03" "NA19239.r1.H04"
# [665] "NA19239.r1.H05" "NA19239.r1.H06" "NA19239.r1.H07" "NA19239.r1.H08"
# [669] "NA19239.r1.H09" "NA19239.r1.H10" "NA19239.r1.H11" "NA19239.r1.H12"
# [673] "NA19239.r2.A01" "NA19239.r2.A02" "NA19239.r2.A03" "NA19239.r2.A04"
# [677] "NA19239.r2.A05" "NA19239.r2.A06" "NA19239.r2.A07" "NA19239.r2.A08"
# [681] "NA19239.r2.A09" "NA19239.r2.A10" "NA19239.r2.A11" "NA19239.r2.A12"
# [685] "NA19239.r2.B01" "NA19239.r2.B02" "NA19239.r2.B03" "NA19239.r2.B04"
# [689] "NA19239.r2.B05" "NA19239.r2.B06" "NA19239.r2.B07" "NA19239.r2.B08"
# [693] "NA19239.r2.B09" "NA19239.r2.B10" "NA19239.r2.B11" "NA19239.r2.B12"
# [697] "NA19239.r2.C01" "NA19239.r2.C02" "NA19239.r2.C03" "NA19239.r2.C04"
# [701] "NA19239.r2.C05" "NA19239.r2.C06" "NA19239.r2.C07" "NA19239.r2.C08"
# [705] "NA19239.r2.C09" "NA19239.r2.C10" "NA19239.r2.C11" "NA19239.r2.C12"
# [709] "NA19239.r2.D01" "NA19239.r2.D02" "NA19239.r2.D03" "NA19239.r2.D04"
# [713] "NA19239.r2.D05" "NA19239.r2.D06" "NA19239.r2.D07" "NA19239.r2.D08"
# [717] "NA19239.r2.D09" "NA19239.r2.D10" "NA19239.r2.D11" "NA19239.r2.D12"
# [721] "NA19239.r2.E01" "NA19239.r2.E02" "NA19239.r2.E03" "NA19239.r2.E04"
# [725] "NA19239.r2.E05" "NA19239.r2.E06" "NA19239.r2.E07" "NA19239.r2.E08"
# [729] "NA19239.r2.E09" "NA19239.r2.E10" "NA19239.r2.E11" "NA19239.r2.E12"
# [733] "NA19239.r2.F01" "NA19239.r2.F02" "NA19239.r2.F03" "NA19239.r2.F04"
# [737] "NA19239.r2.F05" "NA19239.r2.F06" "NA19239.r2.F07" "NA19239.r2.F08"
# [741] "NA19239.r2.F09" "NA19239.r2.F10" "NA19239.r2.F11" "NA19239.r2.F12"
# [745] "NA19239.r2.G01" "NA19239.r2.G02" "NA19239.r2.G03" "NA19239.r2.G04"
# [749] "NA19239.r2.G05" "NA19239.r2.G06" "NA19239.r2.G07" "NA19239.r2.G08"
# [753] "NA19239.r2.G09" "NA19239.r2.G10" "NA19239.r2.G11" "NA19239.r2.G12"
# [757] "NA19239.r2.H01" "NA19239.r2.H02" "NA19239.r2.H03" "NA19239.r2.H04"
# [761] "NA19239.r2.H05" "NA19239.r2.H06" "NA19239.r2.H07" "NA19239.r2.H08"
# [765] "NA19239.r2.H09" "NA19239.r2.H10" "NA19239.r2.H11" "NA19239.r2.H12"
# [769] "NA19239.r3.A01" "NA19239.r3.A02" "NA19239.r3.A03" "NA19239.r3.A04"
# [773] "NA19239.r3.A05" "NA19239.r3.A06" "NA19239.r3.A07" "NA19239.r3.A08"
# [777] "NA19239.r3.A09" "NA19239.r3.A10" "NA19239.r3.A11" "NA19239.r3.A12"
# [781] "NA19239.r3.B01" "NA19239.r3.B02" "NA19239.r3.B03" "NA19239.r3.B04"
# [785] "NA19239.r3.B05" "NA19239.r3.B06" "NA19239.r3.B07" "NA19239.r3.B08"
# [789] "NA19239.r3.B09" "NA19239.r3.B10" "NA19239.r3.B11" "NA19239.r3.B12"
# [793] "NA19239.r3.C01" "NA19239.r3.C02" "NA19239.r3.C03" "NA19239.r3.C04"
# [797] "NA19239.r3.C05" "NA19239.r3.C06" "NA19239.r3.C07" "NA19239.r3.C08"
# [801] "NA19239.r3.C09" "NA19239.r3.C10" "NA19239.r3.C11" "NA19239.r3.C12"
# [805] "NA19239.r3.D01" "NA19239.r3.D02" "NA19239.r3.D03" "NA19239.r3.D04"
# [809] "NA19239.r3.D05" "NA19239.r3.D06" "NA19239.r3.D07" "NA19239.r3.D08"
# [813] "NA19239.r3.D09" "NA19239.r3.D10" "NA19239.r3.D11" "NA19239.r3.D12"
# [817] "NA19239.r3.E01" "NA19239.r3.E02" "NA19239.r3.E03" "NA19239.r3.E04"
# [821] "NA19239.r3.E05" "NA19239.r3.E06" "NA19239.r3.E07" "NA19239.r3.E08"
# [825] "NA19239.r3.E09" "NA19239.r3.E10" "NA19239.r3.E11" "NA19239.r3.E12"
# [829] "NA19239.r3.F01" "NA19239.r3.F02" "NA19239.r3.F03" "NA19239.r3.F04"
# [833] "NA19239.r3.F05" "NA19239.r3.F06" "NA19239.r3.F07" "NA19239.r3.F08"
# [837] "NA19239.r3.F09" "NA19239.r3.F10" "NA19239.r3.F11" "NA19239.r3.F12"
# [841] "NA19239.r3.G01" "NA19239.r3.G02" "NA19239.r3.G03" "NA19239.r3.G04"
# [845] "NA19239.r3.G05" "NA19239.r3.G06" "NA19239.r3.G07" "NA19239.r3.G08"
# [849] "NA19239.r3.G09" "NA19239.r3.G10" "NA19239.r3.G11" "NA19239.r3.G12"
# [853] "NA19239.r3.H01" "NA19239.r3.H02" "NA19239.r3.H03" "NA19239.r3.H04"
# [857] "NA19239.r3.H05" "NA19239.r3.H06" "NA19239.r3.H07" "NA19239.r3.H08"
# [861] "NA19239.r3.H09" "NA19239.r3.H10" "NA19239.r3.H11" "NA19239.r3.H12"
#
# $HVGsID
# logical(0)
#
# $pca
# NULL
#
# $tsne
# NULL
#
# $umap
# NULL
#
# $info
# An object of class Seurat
# 18167 features across 864 samples within 2 assays
# Active assay: ERCC (89 features, 0 variable features)
#  2 layers present: counts, data
#  1 other assay present: originalexp

# %%
print(results$info)
# Out:
# An object of class Seurat
# 18167 features across 864 samples within 2 assays
# Active assay: ERCC (89 features, 0 variable features)
#  2 layers present: counts, data
#  1 other assay present: originalexp

# %%
assay_names <- names(srat_v3@assays)
'RNA' %in% assay_names

# %%
length(assay_names)

# %%
info = print(srat)

# %%
info

# %%
tools::file_path_sans_ext(path)

# %%
# SaveH5Seurat(srat, filename = "/ps/ai-ready/data/Clustering/Tabula_Muris/droplet_Bladder_seurat_tiss.h5Seurat", overwrite = TRUE, verbose = FALSE)
saveRDS(object = srat, file = "/ps/ai-ready/data/Clustering/Tabula_Muris/droplet_Bladder_seurat_tiss.rds")

# %%
robj <- readRDS("/ps/ai-ready/data/Clustering/Tabula_Muris/droplet_Bladder_seurat_tiss.rds")
robj

# %%
srat <- LoadSeurat("//ps/ai-ready/data/Clustering/Tabula_Muris/droplet_Bladder_seurat_tiss.rds")
# srat <- LoadSeurat("/ps/ai-ready/data/Clustering/Tabula_Muris/droplet_Bladder_seurat_tiss.h5Seurat")
srat

# %%
SaveH5Seurat(srat, filename = "/ps/ai-ready/data/Clustering/Tabula_Muris/droplet_Bladder_seurat_tiss.h5Seurat", overwrite = TRUE, verbose = FALSE)
srat <- LoadSeurat("/ps/ai-ready/data/Clustering/Tabula_Muris/droplet_Bladder_seurat_tiss.h5Seurat")
srat

# %%
srat <- tryCatch(
        LoadSeurat(path),
        error = function(e) {
            stop("The file format is not supported.")
            print(e)
        }
    )

# %%
srat

# %%
UMAPPlot(object = srat, label=T)

# %%
srat@meta.data

# %%
colnames(srat[['RNA']])

# %%
srat[['pca']]

# %%
srat <- Seurat::ReadH5AD(path)
srat

# %%
adata <- LoadAnndata(path)
adata

# %%
# Add dimension reduction
  embed_names <- unlist(adata$obsm_keys())
  if (length(embed_names) > 0) {
    embeddings <- sapply(embed_names, function(x) as.matrix(adata$obsm[[x]]), simplify = FALSE, USE.NAMES = TRUE)
    names(embeddings) <- embed_names
      for (name in embed_names) {
        rownames(embeddings[[name]]) <- colnames(srat[['RNA']])
      }
  }

# %%
embeddings

# %%
length(adata$obsm[['X_tsne']])

# %%
adata$obsm[['X_tsne']]

# %%
adata$layers

# %%
adata$layers <- NULL
adata

# %%
'' %in% names(adata$layers)

# %%
names(adata$layers)

# %%
for (layer in names(adata$layers)){
    print(layer)
  }

# %%
is.null(names(adata$layers))

# %%
names(adata$layers) == 'aaa'

# %%
'scale.data' %in% names(adata$layers)

# %%
adata$layers['scale.data']

# %%
srat <- LoadSeurat("/ps/ai-ready/data/Clustering/Tabula_Muris/droplet_Bladder_seurat_tiss.h5Seurat")
srat

# %%
print(srat[['umap']])

# %%
dims=1:10
srat <- FindVariableFeatures(srat, selection.method = "vst")
srat <- ScaleData(srat, features = rownames(srat))

# PCA
# srat <- RunPCA(srat, features = VariableFeatures(srat), ndims.print = 6:10, nfeatures.print = 10)
srat <- RunPCA(srat, features = VariableFeatures(srat))

srat <- FindNeighbors(srat, dims=dims)
srat <- FindClusters(srat, resolution = 0.5)
srat

# TSNE
srat <- RunTSNE(srat, dims=dims)
# UMAP
srat <- RunUMAP(srat, dims=dims)

umap <- Embeddings(object = srat, reduction = "umap")

# %%
embed_names <- unlist(adata$obsm_keys())
embed_names

# %%
adata$obsm[['X_umap']]

# %%
adata$obsm[['X_pca']]

# %%
as.matrix(adata$obsm[['X_pca']])

# %%
adata_Seurat <- CreateSeuratObject(counts = t(adata$X), meta.data = adata$obs)
adata_Seurat

# %%
adata_Seurat$data

# %%
if (reticulate::py_to_r(sp$issparse(adata$X))) {
      X <- Matrix::t(reticulate::py_to_r(sp$csc_matrix(adata$X)))
    } else {
      X <- t(reticulate::py_to_r(adata$X))
    }

# %%
adata$X

# %%
.obs2metadata <- function(obs_pd, assay = "RNA") {
  obs_df <- .regularise_df(obs_pd, drop_single_values=FALSE, drop_na_values=TRUE)
  colnames(obs_df) <- sub("n_counts", paste0("nCounts_", assay), colnames(obs_df))
  colnames(obs_df) <- sub("n_genes", paste0("nFeaturess_", assay), colnames(obs_df))
  return(obs_df)
}

#' Prepare feature metadata
#'
#' This function prepare feature metadata from AnnData.var
#'
#' @param var_pd Input AnnData.var dataframe
#'
#' @return AnnData object
#'
#' @import reticulate
.var2feature_metadata <- function(var_pd) {
  var_df <- .regularise_df(var_pd, drop_single_values=FALSE, drop_na_values=TRUE)
  colnames(var_df) <- sub("dispersions_norm", "mvp.dispersion.scaled", colnames(var_df))
  colnames(var_df) <- sub("dispersions", "mvp.dispersion", colnames(var_df))
  colnames(var_df) <- sub("means", "mvp.mean", colnames(var_df))
  colnames(var_df) <- sub("highly_variable", "highly.variable", colnames(var_df))
  return(var_df)
}

# %%
obs_df <- .obs2metadata(adata$obs)
var_df <- .var2feature_metadata(adata$var)
X <- t(adata$X)
colnames(X) <- rownames(obs_df)
rownames(X) <- rownames(var_df)
X

# %%
rownames(obs_df)

# %%
rownames(var_df)

# %%
obs_df

# %%
x_t <- Matrix::t(adata$X)
x_t

# %%
adata_Seurat$RNA$counts

# %%
adata_Seurat$RNA$counts

# %%
Convert(path, "h5seurat", overwrite = TRUE)

# %%
srat <- LoadH5Seurat(paste0(tools::file_path_sans_ext(path), ".h5seurat"), meta.data = FALSE, misc = FALSE)

# %%
library(Seurat)
library(SingleCellExperiment)
library(SeuratDisk)
library(SeuratData)
input = "/ps/ai-ready/data/error/tung.rds"
robj <- readRDS(input)
robj

# %%
logcounts(robj)

# %%
'logcounts'  %in% names(robj)

# %%
srat <- as.Seurat(robj, slot = "counts")

# %%
# path <- "/ps/ai-ready/data/Clustering/Tabula_Muris/droplet_Bladder_seurat_tiss.Robj"
path <- "/ps/ai-ready/data/Clustering/Tabula_Muris/droplet_Bladder_seurat_tiss.h5Seurat"

# %%
srat <- LoadSeurat(path)
srat

# %%
adata <- SeuratToAnndata(srat)
adata

# %%
adata$X

# %%
obj <- srat
default_assay <- 'RNA'
if(paste0("nCount_", default_assay) %in% names(obj@meta.data)) names(obj@meta.data)[names(obj@meta.data) ==paste0("nCount_", default_assay)] <-"n_counts"
if(paste0("nFeature_", default_assay) %in% names(obj@meta.data)) names(obj@meta.data)[names(obj@meta.data) ==paste0("nFeature_", default_assay)] <-"n_genes"
if("percent.mt" %in% names(obj@meta.data)) names(obj@meta.data)[names(obj@meta.data) =="percent.mt"] <-"percent_mito"
obj@meta.data

# %%
adata$layers['scale.data']

# %%
srat[['RNA']]@counts

# %%
mat <- Seurat::GetAssayData(object=srat, assay='RNA', layer='X')

# %%
default_assay <- DefaultAssay(srat)
default_assay

# %%
adata <- LoadAnndata("/ps/ai-ready/data/Clustering/Tabula_Muris/droplet_Bladder_seurat_tiss.h5ad")
adata

# %%
adata$obsm['X_pca']

# %%
Embeddings(object = srat, reduction = "pca")

# %%
max(srat[['RNA']]@counts)

# %%
min(srat[['RNA']]@counts)

# %%
doublet_annnotation <- AnnotateDroplet(srat[[default_assay]]@counts)

# %%
doublet_annnotation$doublet_score

# %%
srat[["Doublet_score"]] <- doublet_annnotation$doublet_score
srat[["Doublet_class"]] <- doublet_annnotation$doublet_class

# %%
data_mat = srat[['RNA']]@counts

# %%
# -i data_mat -o doublet_score -o doublet_class

set.seed(123)
sce = scDblFinder(
    SingleCellExperiment(
        list(counts=data_mat),
    ) 
)
doublet_score = sce$scDblFinder.score
doublet_class = sce$scDblFinder.class

# %%
srat[["Doublet_score"]] <- doublet_score

# %%
srat[["Doublet_class"]] <- doublet_class

# %%
srat[[]]

# %%
dim(srat[['RNA']]@counts)
dim(srat)
dim(srat@meta.data)

# %%
if(!paste0("nCount_", default_assay) %in% names(x = srat[[]])) srat[[paste0("nCount_", default_assay)]] <- colSums(x = srat[[default_assay]], slot = "counts")  # nCount of the default assay
if(!paste0("nFeature_", default_assay) %in% names(x = srat[[]])) srat[[paste0("nFeature_", default_assay)]] <- colSums(x = GetAssayData(object = srat[[default_assay]], slot = "counts") > 0)  # nFeature of the default assay

# %%
head(srat@meta.data)

# %%
output_path <- '/ps/ai-ready/data/Clustering/Tabula_Muris/droplet_Bladder_seurat_tiss.h5Seurat'
SaveH5Seurat(srat, filename = output_path, overwrite = TRUE, verbose = TRUE)

# %%
srat1 <- LoadH5Seurat(output_path)
srat1

# %%
srat1@meta.data

# %%
adata_path <- Convert('/ps/ai-ready/data/Clustering/Tabula_Muris/droplet_Bladder_seurat_tiss.h5Seurat', dest = "h5ad" , overwrite = TRUE)
adata_path

# %%
# Calculate the percentage of mitocondrial per cell and add to the metadata.
if(! "percent.mt" %in% names(x = srat[[]])) srat[["percent.mt"]] <- PercentageFeatureSet(srat, pattern = "^MT-")
# Calculate the proportion gene expression that comes from ribosomal proteins.
if(! "percent.rb" %in% names(x = srat[[]])) srat[["percent.rb"]] <- PercentageFeatureSet(srat, pattern = "^RP[SL]")

# Percentage hemoglobin genes - includes all genes starting with HB except HBP.
if(! "percent.hb" %in% names(x = srat[[]])) srat[["percent.hb"]] <- PercentageFeatureSet(srat, pattern = "^HB[^(P)]")
if(! "percent.plat" %in% names(x = srat[[]])) srat[["percent.plat"]] <- PercentageFeatureSet(srat, pattern = "PECAM1|PF4")
head(srat@meta.data)

# %%
# Add the doublet annotation
doublets <- read.table(here::here('api/tools/qc/scrublet_calls.tsv'), header = F, row.names = 1)
colnames(doublets) <- c("Doublet_score", "Is_doublet")
srat <- AddMetaData(srat, doublets)
# srat[['Is_doublet']] <- !is.na(srat[['Is_doublet']])

# %%
head(srat@meta.data)

# %%
srat@meta.data

# %%
names(srat@meta.data)[names(srat@meta.data) =="nCount_RNA"] <-"n_counts"
srat@meta.data

# %%
names(srat@meta.data)

# %%
nFeature_min=200
nFeature_max=0
percent_mt_max=5
percent_rb_min=0
srat <- subset(srat, subset = paste0("nFeature_", default_assay) > nFeature_min & percent.mt < percent_mt_max)
if(nFeature_max != 0) srat <- subset(srat, subset = paste0("nFeature_", default_assay) < nFeature_max)
if(percent_rb_min != 0)  srat <- subset(srat, subset = percent.rb > percent_rb_min)

# %%
srat <- subset(srat, subset = Is_doublet != 'True' | is.na(Is_doublet))

# %%
#' Regularise dataframe
#'
#' This function checks if certain columns of a dataframe is of a single value
#' and drop them if required
#'
#' @param df Input data frame, usually cell metadata table (data.frame-like
#'   object)
#' @param drop_single_values Drop columns with only a single value (logical)
#'
#' @return Dataframe
.regularise_df <- function(df, drop_single_values=FALSE, drop_na_values=TRUE) {
  if (ncol(df) == 0) df[["name"]] <- rownames(df)
  if (drop_single_values) {
    k_singular <- sapply(df, function(x) length(unique(x)) == 1)
    if (sum(k_singular) > 0) {
      warning(
        paste("Dropping single category variables:"),
        paste(colnames(df)[k_singular], collapse = ", ")
      )
    }
    df <- df[, !k_singular, drop = F]
    if (ncol(df) == 0) df[["name"]] <- rownames(df)
  }
 if (drop_na_values) {
    k_na <- sapply(srat@meta.data, function(x) sum(is.na(x))==length(x))
    if (sum(k_na) > 0) {
      warning(
        paste("Dropping NA category variables:"),
        paste(colnames(df)[k_na], collapse = ", ")
      )
    }
    df <- df[, !k_na, drop = F]
    if (ncol(df) == 0) df[["name"]] <- rownames(df)
  }
  return(df)
}

# %%
output_path_rds <- '/ps/ai-ready/data/Clustering/Tabula_Muris/droplet_Bladder_seurat_tiss.rds'
saveRDS(srat, output_path_rds)
srat1 <- LoadSeurat(output_path_rds)
srat1

# %%
k_na <- sapply(srat@meta.data, function(x) sum(is.na(x))==length(x))
k_na
sum(k_na)

# %%
srat_qc@meta.data %>% is.na()

# %%
k_singular <- sapply(srat_qc@meta.data, function(x) length(unique(x)) == 1)
k_singular

# %%
srat_qc@meta.data

# %%
srat@meta.data <- .regularise_df(srat@meta.data, drop_single_values=FALSE, drop_na_values=TRUE)
srat@meta.data

# %%
srat_qc@meta.data <- .regularise_df(srat_qc@meta.data, drop_single_values = FALSE)
srat_qc@meta.data

# %%
output_path <- '/ps/ai-ready/data/Clustering/Tabula_Muris/droplet_Bladder_seurat_tiss.h5Seurat'
SaveH5Seurat(srat_qc, filename = output_path, overwrite = TRUE, verbose = TRUE)
srat_3 <- LoadH5Seurat(output_path)
srat_3

# %%
output_path <- '/ps/ai-ready/data/Clustering/Tabula_Muris/droplet_Bladder_seurat_tiss.h5Seurat'
SaveH5Seurat(srat1, filename = output_path, overwrite = TRUE, verbose = TRUE)
srat_2 <- LoadH5Seurat(output_path)
srat_2

# %%
srat1[["meta.data"]]

# %%
srat1@meta.data

# %%
devtools::install_github("cellgeni/sceasy")

# %%
sceasy::convertFormat(srat1, from="seurat", to="anndata",
                       outFile='/ps/ai-ready/data/Clustering/Tabula_Muris/droplet_Bladder_seurat_tiss.h5ad')

# %%
adata <- LoadAnndata('/ps/ai-ready/data/Clustering/Tabula_Muris/droplet_Bladder_seurat_tiss.h5ad')
adata

# %%
adata$obs

# %%
adata$X

# %%
srat_qc <- CreateSeuratObject(counts=srat[['RNA']]@counts, meta.data=srat@meta.data, project = Project(srat))
srat_qc

# %%
output_path <- '/ps/ai-ready/data/Clustering/Tabula_Muris/droplet_Bladder_seurat_tiss.h5Seurat'
SaveH5Seurat(srat_qc, filename = output_path, overwrite = TRUE, verbose = TRUE)
srat_qc_1 <- LoadH5Seurat(output_path)
srat_qc_1

# %%
output_path <- '/ps/ai-ready/data/Clustering/Tabula_Muris/droplet_Bladder_seurat_tiss.h5Seurat'
SaveH5Seurat(srat, filename = output_path, overwrite = TRUE, verbose = TRUE)
srat1 <- LoadH5Seurat(output_path)
srat1

# %%
srat <- subset(srat, subset = Is_doublet != 'True')

# %%
srat[["meta.data"]]

# %%
Cells(srat)

# %%
srat <- NormalizeData(srat, normalization.method = "LogNormalize", scale.factor = 10000)
srat <- FindVariableFeatures(srat, selection.method = "vst")
srat <- ScaleData(srat, features = rownames(srat))
srat
dim(srat)
dim(srat@meta.data)

# %%
srat[['Doublet_score']][sapply(srat[['Doublet_score']], is.na)] <- 0
srat[['Doublet_score']]

# %%
srat[['Doublet_score']] <- !is.na(srat[['Doublet_score']])

# %%
# srat <- subset(srat, subset = percent.rb >= 0)
srat <- subset(srat, subset = is.na(Is_doublet))
srat

# %%
srat[['Is_doublet']] <- !is.na(srat[['Is_doublet']])

# %%
srat <- subset(srat, subset = Is_doublet != 'True')
srat

# %%
srat@meta.data

# %%
'nCount_RNA' %in% names(srat@meta.data)

# %%
result <- GetMetadataFromSeurat(path)
result

# %%
suffix <- tolower(get_suffix(path))
suffix

# %%
seurat_object <- LoadSeurat(path)
seurat_object

# %%
'umap' %in% names(seurat_object@reductions)

# %%
genes <- rownames(seurat_object)
typeof(genes)
genes

# %%
cells <- Cells(seurat_object)
typeof(cells)
cells

# %%
pca <- Embeddings(object = seurat_object, reduction = "pca")
typeof(pca)
pca

# %%
name <- load(path)
seurat_object <- UpdateSeuratObject(get(name))

# %%
seurat_object

# %%
features <- seurat_object[['RNA']]@var.features
typeof(features)
features

# %%
#获取当前用的Idents
Idents(seurat_object)
levels(seurat_object)

# %%
#总数目
nCells <- ncol(seurat_object)
nGenes <- nrow(seurat_object)

nCells
nGenes

# %%
dim=1:10
class(dim)

# %%
x <- 1:10
x

# %%
class(x)

# %%
devtools::install_github('JiekaiLab/dior')

# %%
source("../tools/benchmarks/clustering/seurat.R")
path = "/ps/ai-ready/data/Clustering/Tabula_Muris/droplet_Bladder_seurat_tiss.h5ad"

# %%
clustering <- function(path, labels, dims=1:10){ # labels: column name of labels in srat@meta.data
    srat <- tryCatch(
        LoadSeurat(path),
        error = function(e) {
            stop("The file format is not supported.")
            print(e)
        }
    )

    srat <- FindVariableFeatures(srat, selection.method = "vst")
    srat <- ScaleData(srat, features = rownames(srat))

    # PCA
    # srat <- RunPCA(srat, features = VariableFeatures(srat), ndims.print = 6:10, nfeatures.print = 10)
    srat <- RunPCA(srat, features = VariableFeatures(srat))

    srat <- FindNeighbors(srat, dims=dims)
    srat <- FindClusters(srat, resolution = 0.5)
    srat

    # TSNE
    srat <- RunTSNE(srat, dims=dims)
    # UMAP
    srat <- RunUMAP(srat, dims=dims)

    umap <- Embeddings(object = srat, reduction = "umap")

    list(labels=as.list(srat@meta.data[labels]), labels_pred=as.list(srat@meta.data["seurat_clusters"]), umap=umap)
}

# %%
result <- clustering(path, 'cluster.ids')
result

# %%
result
